# %% [markdown]
# <div align="center">
#     <img src="images/zb-logo.png" alt="제로베이스" width="100%">
#     <br>
#     <a href="https://zerobaseschool.notion.site/DS-EDA-Lv-Test-b7d5e895c7cd4dda813c8fe2f2c23f79"><img src="images/openinnotion_logo.png" alt="EDA Lv Test Doc" width="12%"></a>
#
# 이 Jupyter Notebook 파일은 <a href="https://zero-base.co.kr/category_data_camp/school_DS">제로베이스</a>에서 제공하는 **EDA Level Test** 문제입니다.<br>
# 지금까지 공부하신 내용으로 데이터 분석에 대해 좀 더 연습할 수 있는 시간이 되셨으면 좋겠습니다.🙂<br>
# **EDA Level Test**에 대한 안내 사항은 상단 **Open in ZeroBase Notion** 로고를 클릭하여 확인해주세요!<br>
# 반드시 시작 전에 내용을 숙지해주시기를 바랍니다!<br>
# </div>
#
# ***

# %% [markdown]
# <h1 style="background-color:#9F81F7;color:#D8D8D8;font-weight:bold;display:inline-block;padding: 5px">EDA Level Test 05 ⭐️⭐️</h1>
#
# | Week | Data Analysis | Difficulty | This Notebook |
# |------|---------------|------------|-------|
# | 1    | 서울시 인구 데이터 | ⭐️ ||
# | 2    | 화장품 성분 데이터 | ⭐️⭐️⭐️ ||
# | 3    | 올림픽 데이터 | ⭐️⭐️ ||
# | 4    | 국가별 인터넷 사용률 데이터 |⭐️⭐️ ||
# | 5    | 전국 박물관/미술관 정보 표준 데이터 | ⭐️⭐️⭐️ |👈|
# | 6    | 서울시 흡연율 통계 데이터 | ⭐️⭐️ ||
# | 7    | 웹크롤링 | ⭐️ ||
# | 8    | 서울시 지하철 호선별 역별 유/무임 승하차 인원 정보 데이터 | ⭐️⭐️ ||
# | 9    | 서울시 교통사고 현황 (사고유형별) 통계 데이터 | ⭐️⭐️ ||
# | 10   | 서울시 교통사고 현황 (사고유형별) 통계 + 서울시 차량통행속도 (구별/월별) 통계 + 서울시 인구밀도 (구별) 통계 | ⭐️⭐️⭐️ ||

# %% [markdown]
# ## 문제 소개 및 데이터 준비 단계
#
# ### Target Data(Json): 전국박물관미술관정보표준데이터
# - Source: [공공데이터포털](https://www.data.go.kr/data/15017323/standard.do)
# - DownLoad: [전국박물관미술관정보표준데이터.json](https://www.data.go.kr/download/15017323/standard.do?dataType=json)
#
#
# ### 참고사항
# - 공공데이터포털에서 해당 데이터는 다양한 Format(xls, xml, json, rdf, csv)으로 제공합니다.
# <br></br>
# - 다양한 Data Format 사용을 하고자 해당 Test에서는 일부러 json format의 데이터를 사용할 예정입니다.
#     - json 상세 설명: https://www.json.org/json-ko.html
# <br></br>
# - 문제에 hint가 있을 경우, 해당 hint를 이용하지 않으셔도 무방합니다.

# %%
import json
# 채점을 위한 코드입니다. 반드시 실행해주세요.
from grading import *

with open('./datas/전국박물관미술관정보표준데이터.json', 'r', encoding='utf-8') as f:
    json_data = json.load(f)

# %% [markdown]
# ## 문제 시작! 🏃🏻

# %% [markdown]
# ## 1단계: Json Data로 DataFrame으로 만들기
# ***

# %% [markdown]
# ### 문제 1-1) Json Data로 Pandas DataFrame 만들기 (10점)
# - 위에서 읽은 json_data는 아래와 같이 구성되어있습니다. 이를 참고하여 pandas dataframe으로 불러오세요.
# <br></br>
#     - json_data
#         - json_data['fields']: List. 각 variable은 하나의 Column(열)을 의미하며, {id: Column(열)명}의 형식으로 구성 되어있습니다.
#         - json_data['records']: List. 각 variable은 하나의 Row(행)을 의미하며, {Column(열)명: data}의 형식으로 구성 되어있습니다.
# <br></br>
#         - 예시
# <br></br>
#         <img src="images/05-1-1-001.png" style="margin:auto" width=800/>
# <br></br>
#     - 조건1: 위의 내용을 참고하여 'json_data'를 이용하여 Pandas DataFrame을 만드세요
# <br></br>
#     - 조건2: json data의 Index와 Column(열)의 순서(order)는 변경하지 마세요.
#         - 앞에서부터 순차적으로 차례로 읽어 그대로 DataFrame으로 만드세요.
# <br></br>
#     - 조건3: 'df_target' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
#     - hint: pandas의 read_json method로는 읽어지지 않습니다.
#         - 공공데이터포털에서 json data를 만드는 형식이 read_json과 matching되지 않아 Error가 발생합니다.
# <br></br>
# <br></br>
# - 완료 후 결과 DataFrame 변수(df_target)를 check_01_01 함수에 입력하여 채점하세요.

# %%
json_data['fields']
# Out:
# [{'id': '시설명'},
#  {'id': '박물관미술관구분'},
#  {'id': '소재지도로명주소'},
#  {'id': '소재지지번주소'},
#  {'id': '위도'},
#  {'id': '경도'},
#  {'id': '운영기관전화번호'},
#  {'id': '운영기관명'},
#  {'id': '운영홈페이지'},
#  {'id': '편의시설정보'},
#  {'id': '평일관람시작시각'},
#  {'id': '평일관람종료시각'},
#  {'id': '공휴일관람시작시각'},
#  {'id': '공휴일관람종료시각'},
#  {'id': '휴관정보'},
#  {'id': '어른관람료'},
#  {'id': '청소년관람료'},
#  {'id': '어린이관람료'},
#  {'id': '관람료기타정보'},
#  {'id': '박물관미술관소개'},
#  {'id': '교통안내정보'},
#  {'id': '관리기관전화번호'},
#  {'id': '관리기관명'},
#  {'id': '데이터기준일자'},
#  {'id': '제공기관코드'},
#  {'id': '제공기관명'}]

# %%
json_data['records']
# Out:
# [{'시설명': '풀짚공예박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 광주시 오포읍 문형산길 76',
#   '소재지지번주소': '',
#   '위도': '37.36419778',
#   '경도': '127.1651063',
#   '운영기관전화번호': '031-717-4538',
#   '운영기관명': '풀짚공예박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:30',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '3000',
#   '청소년관람료': '1500',
#   '어린이관람료': '1500',
#   '관람료기타정보': '특별전시입장료-일반(3000)+특별전시입장료-미취학(1500)+특별전시입장료-유치원+초등학생(1500)+특별전시입장료-청소년 (1500)+특별전시입장료-19~25세 (3000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-717-4538',
#   '관리기관명': '풀짚공예박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '프라움 악기박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 남양주시 와부읍 경강로 756',
#   '소재지지번주소': '',
#   '위도': '37.56850845',
#   '경도': '127.2270492',
#   '운영기관전화번호': '031-521-6043',
#   '운영기관명': '프라움악기박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '23:59',
#   '휴관정보': '홈페이지 참조 (* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '5000',
#   '청소년관람료': '4000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-521-6043',
#   '관리기관명': '프라움 악기박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '피노키오뮤지엄',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 파주시 회동길 152(문발동)',
#   '소재지지번주소': '',
#   '위도': '37.70890656',
#   '경도': '126.6875615',
#   '운영기관전화번호': '02-3144-3700',
#   '운영기관명': '피노지움',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:30',
#   '평일관람종료시각': '18:30',
#   '공휴일관람시작시각': '10:30',
#   '공휴일관람종료시각': '18:30',
#   '휴관정보': '월+설 연휴+추석 연휴',
#   '어른관람료': '8000',
#   '청소년관람료': '8000',
#   '어린이관람료': '8000',
#   '관람료기타정보': '특별전시입장료-일반(6000~8000)+특별전시입장료-미취학(6000~8000)+특별전시입장료-유치원+초등학생(6000~8000)+특별전시입장료-청소년 (6000)+특별전시입장료-19~25세 (8000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-3144-3700',
#   '관리기관명': '피노키오뮤지엄',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한과문화박물관한가원',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 포천시 영북면 산정호수로 322번길 26-9',
#   '소재지지번주소': '',
#   '위도': '38.0683553',
#   '경도': '127.3037277',
#   '운영기관전화번호': '031-533-8121',
#   '운영기관명': '한과문화박물관한가원',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '연중무휴',
#   '어른관람료': '3000',
#   '청소년관람료': '1500',
#   '어린이관람료': '1500',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-533-8121',
#   '관리기관명': '한과문화박물관한가원',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한국근현대사박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 파주시 탄현면 헤이리마을길 59-85',
#   '소재지지번주소': '',
#   '위도': '37.79087109',
#   '경도': '126.6952001',
#   '운영기관전화번호': '031-957-1125',
#   '운영기관명': '한국근현대사박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:30',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:30',
#   '공휴일관람종료시각': '19:00',
#   '휴관정보': '월+설 연휴+추석 연휴',
#   '어른관람료': '7000',
#   '청소년관람료': '5000',
#   '어린이관람료': '5000',
#   '관람료기타정보': '특별전시입장료-일반(7000)+특별전시입장료-미취학(5000)+특별전시입장료-유치원+초등학생(5000)+특별전시입장료-청소년 (5000)+특별전시입장료-19~25세 (7000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-957-1125',
#   '관리기관명': '한국근현대사박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한국기독교역사박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 이천시 대월면 대평로 214번길 10-13',
#   '소재지지번주소': '',
#   '위도': '37.22281426',
#   '경도': '127.4992497',
#   '운영기관전화번호': '031-632-1391',
#   '운영기관명': '(재)한국기독교역사박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '월+일+1월 1일+5월 5일+설 연휴+추석 연휴',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-632-1391',
#   '관리기관명': '한국기독교역사박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한국등잔 박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 용인시 처인구 모현읍 능곡로56번길 8',
#   '소재지지번주소': '',
#   '위도': '37.33658645',
#   '경도': '127.1778809',
#   '운영기관전화번호': '031-334-0797',
#   '운영기관명': '한국등잔박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+화+1월 1일+설 당일+추석 당일',
#   '어른관람료': '5000',
#   '청소년관람료': '3000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '특별전시입장료-일반(5000)+특별전시입장료-유치원+초등학생(3000)+특별전시입장료-청소년 (3000)+특별전시입장료-19~25세 (3000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-334-0797',
#   '관리기관명': '한국등잔 박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한국민속촌박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 용인시 기흥구 민속촌로 90',
#   '소재지지번주소': '',
#   '위도': '37.25913189',
#   '경도': '127.1225431',
#   '운영기관전화번호': '031-288-0000',
#   '운영기관명': '조원관광진흥㈜',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:30',
#   '평일관람종료시각': '18:30',
#   '공휴일관람시작시각': '09:30',
#   '공휴일관람종료시각': '19:00',
#   '휴관정보': '(* 향후 업데이트 예정. 필요 시 기관으로 문의 요망)',
#   '어른관람료': '18000',
#   '청소년관람료': '15000',
#   '어린이관람료': '13000',
#   '관람료기타정보': '특별전시입장료-일반(18000)+특별전시입장료-미취학(13000)+특별전시입장료-유치원+초등학생(13000)+특별전시입장료-청소년 (15000)+',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-288-2924',
#   '관리기관명': '한국민속촌박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한국카메라박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 과천시 대공원광장로 8',
#   '소재지지번주소': '',
#   '위도': '37.43505387',
#   '경도': '127.0056677',
#   '운영기관전화번호': '02-502-4123',
#   '운영기관명': '한국카메라박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+일',
#   '어른관람료': '5000',
#   '청소년관람료': '4000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '특별전시입장료-일반(5000)+특별전시입장료-미취학(3000)+특별전시입장료-유치원+초등학생(3000)+특별전시입장료-청소년 (4000)+특별전시입장료-19~25세 (5000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-502-4123',
#   '관리기관명': '한국카메라박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한국탁본자료관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 남양주시 와부읍 도심길 16',
#   '소재지지번주소': '',
#   '위도': '37.58051508',
#   '경도': '127.2225551',
#   '운영기관전화번호': '031-521-1497',
#   '운영기관명': '개인',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '토+일+공휴일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-521-1497',
#   '관리기관명': '한국탁본자료관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한길책박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 파주시 탄현면 헤이리마을길 59-6',
#   '소재지지번주소': '',
#   '위도': '37.78926001',
#   '경도': '126.697936',
#   '운영기관전화번호': '031-949-9786',
#   '운영기관명': '한길책박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '11:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '11:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+설 연휴+추석 연휴',
#   '어른관람료': '6000',
#   '청소년관람료': '4000',
#   '어린이관람료': '4000',
#   '관람료기타정보': '특별전시입장료-일반(6000)+특별전시입장료-미취학(4000)+특별전시입장료-유치원+초등학생(4000)+특별전시입장료-청소년 (4000)+특별전시입장료-19~25세 (6000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-949-9786',
#   '관리기관명': '한길책박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한얼고문서유물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 여주시 대신면 대신1로 298',
#   '소재지지번주소': '',
#   '위도': '37.39865465',
#   '경도': '127.6092433',
#   '운영기관전화번호': '031-881-6319',
#   '운영기관명': '한얼고문서유물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '공휴일 (* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '5000',
#   '청소년관람료': '4000',
#   '어린이관람료': '4000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-881-6319',
#   '관리기관명': '한얼고문서유물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한얼과학문화관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 여주시 대신면 대신1로 298',
#   '소재지지번주소': '',
#   '위도': '37.39865465',
#   '경도': '127.6092433',
#   '운영기관전화번호': '031-881-6319',
#   '운영기관명': '한얼과학문화관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '공휴일 (* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '5000',
#   '청소년관람료': '4000',
#   '어린이관람료': '4000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-881-6319',
#   '관리기관명': '한얼과학문화관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한얼산업디자인유물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 여주시 대신면 대신1로 298',
#   '소재지지번주소': '',
#   '위도': '37.39865465',
#   '경도': '127.6092433',
#   '운영기관전화번호': '031-881-6319',
#   '운영기관명': '한얼산업디자인유물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '공휴일 (* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '5000',
#   '청소년관람료': '4000',
#   '어린이관람료': '4000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-881-6319',
#   '관리기관명': '한얼산업디자인유물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한얼의학유물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 여주시 대신면 대신1로 298',
#   '소재지지번주소': '',
#   '위도': '37.39865465',
#   '경도': '127.6092433',
#   '운영기관전화번호': '031-881-6319',
#   '운영기관명': '한얼의학유물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '공휴일 (* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '5000',
#   '청소년관람료': '4000',
#   '어린이관람료': '4000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-881-6319',
#   '관리기관명': '한얼의학유물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한얼전적유물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 여주시 대신면 대신1로 298',
#   '소재지지번주소': '',
#   '위도': '37.39865465',
#   '경도': '127.6092433',
#   '운영기관전화번호': '031-881-6319',
#   '운영기관명': '한얼전적유물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '공휴일 (* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '5000',
#   '청소년관람료': '4000',
#   '어린이관람료': '4000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-881-6319',
#   '관리기관명': '한얼전적유물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한얼카메라유물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 여주시 대신면 대신1로 298',
#   '소재지지번주소': '',
#   '위도': '37.39865465',
#   '경도': '127.6092433',
#   '운영기관전화번호': '031-881-6319',
#   '운영기관명': '한얼카메라유물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '공휴일 (* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '5000',
#   '청소년관람료': '4000',
#   '어린이관람료': '4000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-881-6319',
#   '관리기관명': '한얼카메라유물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '한향림옹기박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 파주시 탄현면 헤이리마을길 96-43',
#   '소재지지번주소': '',
#   '위도': '37.789956',
#   '경도': '126.7009185',
#   '운영기관전화번호': '031-948-1001',
#   '운영기관명': '한향림옹기박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+화+설 연휴+추석 연휴',
#   '어른관람료': '3000',
#   '청소년관람료': '3000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '특별전시입장료-일반(3000)+특별전시입장료-유치원+초등학생(3000)+특별전시입장료-청소년 (3000)+특별전시입장료-19~25세 (3000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-948-1001',
#   '관리기관명': '한향림옹기박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '허브아일랜드식물원',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 포천시 신북면 청신로 947번길 35',
#   '소재지지번주소': '',
#   '위도': '37.96592509',
#   '경도': '127.1317081',
#   '운영기관전화번호': '031-535-6495',
#   '운영기관명': '포천허브아일랜드',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-535-6495',
#   '관리기관명': '허브아일랜드식물원',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '호암미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 용인시 처인구 포곡읍 에버랜드로 562번길 38',
#   '소재지지번주소': '',
#   '위도': '37.29321667',
#   '경도': '127.1923338',
#   '운영기관전화번호': '031-320-1801',
#   '운영기관명': '호암미술관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+1월 1일+설 연휴+추석 연휴',
#   '어른관람료': '4000',
#   '청소년관람료': '3000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-2014-6537',
#   '관리기관명': '호암미술관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '화폐박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 파주시 탄현면 헤이리마을길 93-89',
#   '소재지지번주소': '',
#   '위도': '37.79080447',
#   '경도': '126.6973166',
#   '운영기관전화번호': '031-949-6592',
#   '운영기관명': '화폐박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+설 연휴+추석 연휴',
#   '어른관람료': '3000',
#   '청소년관람료': '3000',
#   '어린이관람료': '2000',
#   '관람료기타정보': '특별전시입장료-일반(3000)+특별전시입장료-미취학(2000)+특별전시입장료-유치원+초등학생(2000)+특별전시입장료-청소년 (3000)+특별전시입장료-19~25세 (3000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-949-6592',
#   '관리기관명': '화폐박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '청주고인쇄박물관',
#   '박물관미술관구분': '공립',
#   '소재지도로명주소': '충청북도 청주시 흥덕구 직지대로 713',
#   '소재지지번주소': '충청북도 청주시 흥덕구 운천동 866',
#   '위도': '36.6439745',
#   '경도': '127.4714597',
#   '운영기관전화번호': '043-201-4262',
#   '운영기관명': '청주고인쇄박물관',
#   '운영홈페이지': 'jikjiworld.cheongju.go.kr',
#   '편의시설정보': '기념품 판매점, 간이휴게소(3개)',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '매주 월요일, 1월 1일, 설날, 추석',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '043-201-4266',
#   '관리기관명': '청주고인쇄박물관',
#   '데이터기준일자': '2020-07-16',
#   '제공기관코드': '5710000',
#   '제공기관명': '충청북도 청주시'},
#  {'시설명': '여성생활사박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 여주시 강천면 강천로 324-20',
#   '소재지지번주소': '',
#   '위도': '37.2425236',
#   '경도': '127.7081445',
#   '운영기관전화번호': '031-882-8100',
#   '운영기관명': '여성생활사박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '1000',
#   '청소년관람료': '1500',
#   '어린이관람료': '2000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-882-8100',
#   '관리기관명': '여성생활사박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '여주곤충박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 여주시 명성로 114-146',
#   '소재지지번주소': '',
#   '위도': '37.25974736',
#   '경도': '127.6633862',
#   '운영기관전화번호': '031-885-1400',
#   '운영기관명': '농업회사법인㈜ 여주곤충박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '7000',
#   '청소년관람료': '7000',
#   '어린이관람료': '7000',
#   '관람료기타정보': '특별전시입장료-일반(7000)+특별전시입장료-미취학(7000)+특별전시입장료-유치원+초등학생(7000)+특별전시입장료-청소년 (7000)+특별전시입장료-19~25세 (7000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-885-1400',
#   '관리기관명': '여주곤충박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '영집궁시박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 파주시 탄현면 국원말길 168',
#   '소재지지번주소': '',
#   '위도': '37.78492907',
#   '경도': '126.7113666',
#   '운영기관전화번호': '031-944-6800',
#   '운영기관명': '영집궁시박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+설 연휴+추석 연휴',
#   '어른관람료': '0',
#   '청소년관람료': '2500',
#   '어린이관람료': '2000',
#   '관람료기타정보': '특별전시입장료-일반(3000)+특별전시입장료-미취학(2000)+특별전시입장료-유치원+초등학생(2000)+특별전시입장료-청소년 (2500)+특별전시입장료-19~25세 (3000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-944-6800',
#   '관리기관명': '영집궁시박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '예당국악박물관(휴관)',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 남양주시 강변북로661번길 21(수석동)',
#   '소재지지번주소': '',
#   '위도': '37.5899642',
#   '경도': '127.1683819',
#   '운영기관전화번호': '031-590-6981',
#   '운영기관명': '예당국악박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '23:59',
#   '휴관정보': '(* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '5000',
#   '청소년관람료': '3000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '특별전시입장료-일반(5000)+특별전시입장료-미취학(3000)+특별전시입장료-유치원+초등학생(3000)+특별전시입장료-청소년 (3000)+특별전시입장료-19~25세 (5000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-558-4825',
#   '관리기관명': '예당국악박물관(휴관)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '예아리박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 용인시 처인구 백암면 원설로270번길 25',
#   '소재지지번주소': '',
#   '위도': '37.14132389',
#   '경도': '127.3642612',
#   '운영기관전화번호': '031-323-7277',
#   '운영기관명': '예아리박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '5000',
#   '청소년관람료': '4000',
#   '어린이관람료': '4000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-322-7277',
#   '관리기관명': '예아리박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '외할머니의 부엌',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 김포시 대곶면 덕포진로103번길 95-7',
#   '소재지지번주소': '',
#   '위도': '37.64997572',
#   '경도': '126.5389774',
#   '운영기관전화번호': '031-984-1993',
#   '운영기관명': '외할머니의 부엌',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '월',
#   '어른관람료': '2000',
#   '청소년관람료': '2000',
#   '어린이관람료': '1000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-984-1993',
#   '관리기관명': '외할머니의 부엌',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '용주사 효행박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 화성시 용주로 136',
#   '소재지지번주소': '',
#   '위도': '37.21177787',
#   '경도': '127.0056149',
#   '운영기관전화번호': '031-226-3488',
#   '운영기관명': '대한불교조계종 용주사',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '월',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-232-0660',
#   '관리기관명': '용주사 효행박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '우석헌자연사박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 남양주시 진접읍 금강로 1095',
#   '소재지지번주소': '',
#   '위도': '37.69803201',
#   '경도': '127.1608188',
#   '운영기관전화번호': '031-572-9555',
#   '운영기관명': '우석헌자연사박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '19:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '19:00',
#   '휴관정보': '월+일',
#   '어른관람료': '5000',
#   '청소년관람료': '3000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-572-9555',
#   '관리기관명': '우석헌자연사박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '유진민속박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 고양시 덕양구 고양대로1670번길 78-11(원흥동)',
#   '소재지지번주소': '',
#   '위도': '37.64585399',
#   '경도': '126.8657837',
#   '운영기관전화번호': '031-966-5262',
#   '운영기관명': '유진민속박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '월+일+공휴일',
#   '어른관람료': '6000',
#   '청소년관람료': '5000',
#   '어린이관람료': '5000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-966-5262',
#   '관리기관명': '유진민속박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '이풀실내정원',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 안산시 상록구 반월천북길 139-18',
#   '소재지지번주소': '',
#   '위도': '37.3106787',
#   '경도': '126.8892702',
#   '운영기관전화번호': '031-437-2550',
#   '운영기관명': '이풀실내정원',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '11:00',
#   '평일관람종료시각': '22:00',
#   '공휴일관람시작시각': '11:00',
#   '공휴일관람종료시각': '22:00',
#   '휴관정보': '월',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-437-2550',
#   '관리기관명': '이풀실내정원',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '일본군위안부역사관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 광주시 퇴촌면 가새골길 85',
#   '소재지지번주소': '',
#   '위도': '37.44284702',
#   '경도': '127.322019',
#   '운영기관전화번호': '031-768-0064',
#   '운영기관명': '나눔의집',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '월',
#   '어른관람료': '5000',
#   '청소년관람료': '3000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-768-0064',
#   '관리기관명': '일본군위안부역사관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '자연생태박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 부천시 길주로 660',
#   '소재지지번주소': '',
#   '위도': '37.50512868',
#   '경도': '126.8156874',
#   '운영기관전화번호': '032-625-3503',
#   '운영기관명': '자연생태박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:30',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:30',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+1월 1일+설 당일+추석 당일',
#   '어른관람료': '2000',
#   '청소년관람료': '1500',
#   '어린이관람료': '1500',
#   '관람료기타정보': '특별전시입장료-일반(2000)+특별전시입장료-미취학(1000)+특별전시입장료-유치원+초등학생(1500)+특별전시입장료-청소년 (1500)+특별전시입장료-19~25세 (2000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '032-625-3503',
#   '관리기관명': '경기도 부천시청',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '잔아문학박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 양평군 서종면 사랑제길 9-9',
#   '소재지지번주소': '',
#   '위도': '37.59678435',
#   '경도': '127.3547767',
#   '운영기관전화번호': '031-771-8577',
#   '운영기관명': '잔아문학박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+1월 1일+설 당일+추석 당일',
#   '어른관람료': '2000',
#   '청소년관람료': '1500',
#   '어린이관람료': '1000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-771-8577',
#   '관리기관명': '잔아문학박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '조명박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 양주시 광적면 광적로 235-48',
#   '소재지지번주소': '',
#   '위도': '37.83609614',
#   '경도': '126.9675329',
#   '운영기관전화번호': '070-7780-8911',
#   '운영기관명': '조명박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '1월 1일+설 연휴+추석 연휴+필룩스창립기념일(6.20)',
#   '어른관람료': '5000',
#   '청소년관람료': '40000',
#   '어린이관람료': '4000',
#   '관람료기타정보': '특별전시입장료-일반(8000)+특별전시입장료-미취학(12000)+특별전시입장료-유치원+초등학생(12000)+특별전시입장료-청소년 (8000)+특별전시입장료-19~25세 (8000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '070-7780-8000',
#   '관리기관명': '조명박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '조병화문학관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 안성시 양성면 난실길 14-1',
#   '소재지지번주소': '',
#   '위도': '37.11207969',
#   '경도': '127.2216269',
#   '운영기관전화번호': '031-674-0307',
#   '운영기관명': '조병화문학관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:30',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '10:30',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '월+1월 1일+설 연휴+추석 연휴+12월 25일',
#   '어른관람료': '3000',
#   '청소년관람료': '2000',
#   '어린이관람료': '2000',
#   '관람료기타정보': '특별전시입장료-일반(3000)+특별전시입장료-유치원+초등학생(2000)+특별전시입장료-청소년 (2000)+특별전시입장료-19~25세 (3000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-674-0307',
#   '관리기관명': '조병화문학관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '창조자연사박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 시흥시 두문로 71번길 4',
#   '소재지지번주소': '',
#   '위도': '37.43371506',
#   '경도': '126.786472',
#   '운영기관전화번호': '031-435-1009',
#   '운영기관명': '창조자연사박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '월',
#   '어른관람료': '8000',
#   '청소년관람료': '7000',
#   '어린이관람료': '7000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-435-1009',
#   '관리기관명': '창조자연사박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '철도박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 의왕시 철도박물관로 142',
#   '소재지지번주소': '',
#   '위도': '37.3140471',
#   '경도': '126.9512975',
#   '운영기관전화번호': '031-461-3610',
#   '운영기관명': '한국철도공사',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+공휴일 다음날+1월 1일+설 연휴+추석 연휴',
#   '어른관람료': '2000',
#   '청소년관람료': '1000',
#   '어린이관람료': '1000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-461-3610',
#   '관리기관명': '철도박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '청강만화역사박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 이천시 마장면 청강가창로 389-94(해월리) 청강문화산업대학교~ 청강홀 3층',
#   '소재지지번주소': '',
#   '위도': '37.20645349',
#   '경도': '127.3564962',
#   '운영기관전화번호': '031-639-5790',
#   '운영기관명': '청강문화산업대학교',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '토+일+공휴일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-639-5790',
#   '관리기관명': '청강만화역사박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '충현박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 광명시 오리로347번길 5-5',
#   '소재지지번주소': '',
#   '위도': '37.43334079',
#   '경도': '126.8783874',
#   '운영기관전화번호': '02-898-0505',
#   '운영기관명': '충현문화재단',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '월+동절기(12월~2월)',
#   '어른관람료': '3500',
#   '청소년관람료': '2500',
#   '어린이관람료': '2500',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-898-0505',
#   '관리기관명': '충현박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '타임앤블레이드박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 파주시 탄현면 헤이리마을길41',
#   '소재지지번주소': '',
#   '위도': '37.78734981',
#   '경도': '126.6978711',
#   '운영기관전화번호': '031-949-5675',
#   '운영기관명': '타임앤블레이드박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+화+설 연휴+추석 연휴',
#   '어른관람료': '6000',
#   '청소년관람료': '4000',
#   '어린이관람료': '4000',
#   '관람료기타정보': '특별전시입장료-일반(6000)+특별전시입장료-미취학(4000)+특별전시입장료-유치원+초등학생(4000)+특별전시입장료-청소년 (4000)+특별전시입장료-19~25세 (6000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-949-5675',
#   '관리기관명': '타임앤블레이드박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '파주나비나라박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 파주시 광인사길 161',
#   '소재지지번주소': '',
#   '위도': '37.71485123',
#   '경도': '126.6869104',
#   '운영기관전화번호': '031-955-3727',
#   '운영기관명': '파주나비나라박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+설 연휴+추석 연휴',
#   '어른관람료': '4000',
#   '청소년관람료': '5000',
#   '어린이관람료': '5000',
#   '관람료기타정보': '특별전시입장료-일반(6000)+특별전시입장료-미취학(6000)+특별전시입장료-유치원+초등학생(6000)+특별전시입장료-청소년 (6000)+특별전시입장료-19~25세 (6000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-955-3727',
#   '관리기관명': '파주나비나라박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '청주시립미술관',
#   '박물관미술관구분': '공립',
#   '소재지도로명주소': '충청북도 청주시 서원구 충렬로18번길 50',
#   '소재지지번주소': '충청북도 청주시 서원구 사직동 604-26',
#   '위도': '36.63471608',
#   '경도': '127.4782998',
#   '운영기관전화번호': '043-201-2650',
#   '운영기관명': '청주시립미술관',
#   '운영홈페이지': 'www.cmoa.or.kr',
#   '편의시설정보': '카페테리아,물품보관소',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '19:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '19:00',
#   '휴관정보': '매주 월요일, 1월 1일, 설날, 추석 (월요일이 공휴일인 경우 그 다음날 휴관)',
#   '어른관람료': '1000',
#   '청소년관람료': '700',
#   '어린이관람료': '500',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '043-201-2650',
#   '관리기관명': '청주시립미술관',
#   '데이터기준일자': '2020-07-16',
#   '제공기관코드': '5710000',
#   '제공기관명': '충청북도 청주시'},
#  {'시설명': '만해기념관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 광주시 남한산성면 남한산성로 792번길 24-7',
#   '소재지지번주소': '',
#   '위도': '37.47730647',
#   '경도': '127.1808388',
#   '운영기관전화번호': '031-744-3100',
#   '운영기관명': '만해기념관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월(단 월요일이 공휴일인 경우 당일은 개관하고 그 다음 첫번째 평일에 휴관)',
#   '어른관람료': '2000',
#   '청소년관람료': '1000',
#   '어린이관람료': '1000',
#   '관람료기타정보': '특별전시입장료-일반(2000)+특별전시입장료-유치원+초등학생(1000)+특별전시입장료-청소년 (1000)+특별전시입장료-19~25세 (2000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-744-3100',
#   '관리기관명': '만해기념관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '말박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 과천시 경마공원대로 107',
#   '소재지지번주소': '',
#   '위도': '37.44120036',
#   '경도': '127.0161266',
#   '운영기관전화번호': '02-509-1275',
#   '운영기관명': '한국마사회',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+1월 1일+설 연휴+추석 연휴',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '1566-3333',
#   '관리기관명': '말박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '목아박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 여주시 강천면 이문안길 21',
#   '소재지지번주소': '',
#   '위도': '37.28855063',
#   '경도': '127.6881237',
#   '운영기관전화번호': '031-885-9952',
#   '운영기관명': '목아박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '5000',
#   '청소년관람료': '3000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-885-9952',
#   '관리기관명': '목아박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '무의자전시관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 남양주시 평내로 9',
#   '소재지지번주소': '',
#   '위도': '37.64432136',
#   '경도': '127.2309081',
#   '운영기관전화번호': '02-2279-9755',
#   '운영기관명': '(재)무의자재단',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '23:59',
#   '휴관정보': '(* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-591-9667',
#   '관리기관명': '무의자전시관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '미호박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 남양주시 고산로 126번길 15-2',
#   '소재지지번주소': '',
#   '위도': '37.5926636',
#   '경도': '127.1806149',
#   '운영기관전화번호': '031-566-7377',
#   '운영기관명': '미호박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '19:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '20:00',
#   '휴관정보': '1월 1일+설 당일+추석 당일',
#   '어른관람료': '7000',
#   '청소년관람료': '6000',
#   '어린이관람료': '6000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-566-7377',
#   '관리기관명': '미호박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '배다리박물관(휴관)',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 고양시 덕양구 수역이길 120-24(성사동)',
#   '소재지지번주소': '',
#   '위도': '37.65850143',
#   '경도': '126.8462889',
#   '운영기관전화번호': '031-967-8052',
#   '운영기관명': '배다리박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '23:59',
#   '휴관정보': '관람시각 정보 없음',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-967-8052',
#   '관리기관명': '배다리박물관(휴관)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '배다골민속박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 고양시 덕양구 배다골길 131(화정동)',
#   '소재지지번주소': '',
#   '위도': '37.63016535',
#   '경도': '126.8481093',
#   '운영기관전화번호': '031-970-6330',
#   '운영기관명': '배다골민속박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '23:59',
#   '휴관정보': '관람시각 정보 없음',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-970-6330',
#   '관리기관명': '배다골민속박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '벽봉한국장신구박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 파주시 탄현면 헤이리마을길48-38',
#   '소재지지번주소': '',
#   '위도': '37.7876293',
#   '경도': '126.7000633',
#   '운영기관전화번호': '031-949-0848',
#   '운영기관명': '벽봉한국장신구박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '11:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '11:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+화+설 연휴+추석 연휴',
#   '어른관람료': '5000',
#   '청소년관람료': '3000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '특별전시입장료-일반(5000)+특별전시입장료-미취학(3000)+특별전시입장료-유치원+초등학생(3000)+특별전시입장료-청소년 (3000)+특별전시입장료-19~25세 (5000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-949-0848',
#   '관리기관명': '벽봉한국장신구박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '사람박물관 얼굴',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 광주시 남종면 분원길 3-6',
#   '소재지지번주소': '',
#   '위도': '37.49395804',
#   '경도': '127.3020513',
#   '운영기관전화번호': '031-765-3522',
#   '운영기관명': '사람박물관얼굴',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+화',
#   '어른관람료': '4000',
#   '청소년관람료': '3000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '특별전시입장료-일반(4000)+특별전시입장료-미취학(2000)+특별전시입장료-유치원+초등학생(2000)+특별전시입장료-청소년 (3000)+특별전시입장료-19~25세 (4000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-765-3522',
#   '관리기관명': '사람박물관 얼굴',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '삶의이야기가있는집',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 용인시 처인구 원삼면 내동로 50-13',
#   '소재지지번주소': '',
#   '위도': '37.17384579',
#   '경도': '127.2958775',
#   '운영기관전화번호': '031-334-4543',
#   '운영기관명': '청수나눔실천회',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '공휴일 (* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-334-4543',
#   '관리기관명': '삶의이야기가있는집',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '삼성화재교통박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 용인시 처인구 포곡읍 에버랜드로 376번길 171',
#   '소재지지번주소': '',
#   '위도': '37.30037157',
#   '경도': '127.2169538',
#   '운영기관전화번호': '031-320-9900',
#   '운영기관명': '삼성화재',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '1월 1일+설 연휴+추석 연휴',
#   '어른관람료': '6000',
#   '청소년관람료': '5000',
#   '어린이관람료': '5000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-320-9900',
#   '관리기관명': '삼성화재교통박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '세계민속악기박물관(헤이리)',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 파주시 탄현면 헤이리마을길 63-26',
#   '소재지지번주소': '',
#   '위도': '37.78950876',
#   '경도': '126.6993791',
#   '운영기관전화번호': '031-946-9838',
#   '운영기관명': '세계민속악기박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:30',
#   '평일관람종료시각': '17:30',
#   '공휴일관람시작시각': '09:30',
#   '공휴일관람종료시각': '17:30',
#   '휴관정보': '월+설 연휴+추석 연휴',
#   '어른관람료': '5000',
#   '청소년관람료': '4000',
#   '어린이관람료': '4000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-946-9838',
#   '관리기관명': '세계민속악기박물관(헤이리)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '세계인형박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 파주시 탄현면 헤이리마을길 76-100',
#   '소재지지번주소': '',
#   '위도': '37.78690651',
#   '경도': '126.7021051',
#   '운영기관전화번호': '031-947-2575',
#   '운영기관명': '세계인형박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+설 연휴+추석 연휴',
#   '어른관람료': '5000',
#   '청소년관람료': '4000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '특별전시입장료-일반(5000)+특별전시입장료-미취학(3000)+특별전시입장료-유치원+초등학생(3000)+특별전시입장료-청소년 (4000)+특별전시입장료-19~25세 (5000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-947-2575',
#   '관리기관명': '세계인형박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '세주묘엄박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 수원시 팔달구 창룡대로 236-54(우만동)',
#   '소재지지번주소': '',
#   '위도': '37.2915096',
#   '경도': '127.0374974',
#   '운영기관전화번호': '031-256-4127',
#   '운영기관명': '봉녕사',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '16:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '16:00',
#   '휴관정보': '월+설 연휴+추석 연휴',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-256-4127',
#   '관리기관명': '세주묘엄박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '신세계한국상업사박물관(휴관)',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 용인시 처인구 남사읍 화곡로 77',
#   '소재지지번주소': '',
#   '위도': '37.1501125',
#   '경도': '127.1810239',
#   '운영기관전화번호': '031-339-1234',
#   '운영기관명': '신세계한국상업사박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '23:59',
#   '휴관정보': '관람시각 정보 없음',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-339-1234',
#   '관리기관명': '신세계한국상업사박물관(휴관)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '신영숙컬렉션박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 용인시 기흥구 흥덕4로 63',
#   '소재지지번주소': '',
#   '위도': '37.27730736',
#   '경도': '127.0901098',
#   '운영기관전화번호': '031-213-8223',
#   '운영기관명': '신영숙컬렉션박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월 (* 관람시각 정보 없음, 기관으로 확인 요망)',
#   '어른관람료': '9000',
#   '청소년관람료': '5000',
#   '어린이관람료': '5000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-213-8223',
#   '관리기관명': '신영숙컬렉션박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '아해한국전통문화어린이박물관(아해박물관)',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 과천시 추사로 133',
#   '소재지지번주소': '',
#   '위도': '37.45761881',
#   '경도': '127.029979',
#   '운영기관전화번호': '02-3418-5501',
#   '운영기관명': '아해한국전통문화어린이박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '일+설 연휴+추석 연휴',
#   '어른관람료': '5000',
#   '청소년관람료': '5000',
#   '어린이관람료': '5000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-3418-5501',
#   '관리기관명': '아해한국전통문화어린이박물관(아해박물관)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '아프리카예술박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 포천시 소흘읍 광릉수목원로 967',
#   '소재지지번주소': '',
#   '위도': '37.77526972',
#   '경도': '127.1393277',
#   '운영기관전화번호': '031-543-3600',
#   '운영기관명': '아프리카예술박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '5500',
#   '청소년관람료': '5500',
#   '어린이관람료': '4500',
#   '관람료기타정보': '특별전시입장료-일반(5500)+특별전시입장료-미취학(4500)+특별전시입장료-유치원+초등학생(4500)+특별전시입장료-청소년 (5500)+특별전시입장료-19~25세 (5500)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-543-3600',
#   '관리기관명': '아프리카예술박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '양평아프리카문화예술박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 양평군 용문면 금곡길 40',
#   '소재지지번주소': '',
#   '위도': '37.50731557',
#   '경도': '127.6164383',
#   '운영기관전화번호': '031-771-4722',
#   '운영기관명': '개인',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '일+설 연휴+추석 연휴',
#   '어른관람료': '6000',
#   '청소년관람료': '5000',
#   '어린이관람료': '5000',
#   '관람료기타정보': '특별전시입장료-일반(6000)+특별전시입장료-미취학(5000)+특별전시입장료-유치원+초등학생(5000)+특별전시입장료-청소년 (5000)+특별전시입장료-19~25세 (6000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-771-4722',
#   '관리기관명': '양평아프리카문화예술박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '옹청박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 여주시 산북면 금품2로 132',
#   '소재지지번주소': '',
#   '위도': '37.38943856',
#   '경도': '127.4481509',
#   '운영기관전화번호': '031-881-4170',
#   '운영기관명': '옹청박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '13:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '월+토+일+공휴일+1월 1일+국경일 (* 예약 시 예외)',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-881-4157',
#   '관리기관명': '옹청박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '왈츠와 닥터만 커피박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '경기도 남양주시 조안면 북한강로 856-37',
#   '소재지지번주소': '',
#   '위도': '37.591975',
#   '경도': '127.3384565',
#   '운영기관전화번호': '031-576-0020',
#   '운영기관명': '왈츠와 닥터만 커피박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '11:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '11:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+화',
#   '어른관람료': '5000',
#   '청소년관람료': '5000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '특별전시입장료-일반(5000)+특별전시입장료-유치원+초등학생(3000)+특별전시입장료-청소년 (5000)+특별전시입장료-19~25세 (5000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '031-576-0020',
#   '관리기관명': '왈츠와 닥터만 커피박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '조선대학교 박물관',
#   '박물관미술관구분': '대학',
#   '소재지도로명주소': '광주광역시 동구 필문대로 309(서석동,조선대학교)',
#   '소재지지번주소': '',
#   '위도': '35.146003',
#   '경도': '126.934363',
#   '운영기관전화번호': '062-230-6333',
#   '운영기관명': '조선대학교',
#   '운영홈페이지': 'http://www2.chosun.ac.kr/mbs/museum/',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '토+일+공휴일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '조선대학교 박물관은 실물교육자료를 수집·연구·전시하고 교육과 학술 및 지역 발전에 이바지할 목적으로 설립되었습니다',
#   '교통안내정보': '',
#   '관리기관전화번호': '062-230-6333',
#   '관리기관명': '조선대학교',
#   '데이터기준일자': '2022-01-10',
#   '제공기관코드': '3590000',
#   '제공기관명': '광주광역시 동구'},
#  {'시설명': '비움박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '광주광역시 동구 제봉로 143-1(대의동)',
#   '소재지지번주소': '',
#   '위도': '35.150404',
#   '경도': '126.920277',
#   '운영기관전화번호': '062-222-6668',
#   '운영기관명': '비움박물관',
#   '운영홈페이지': 'http://www.biummuseum.com/',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+일',
#   '어른관람료': '10000',
#   '청소년관람료': '7000',
#   '어린이관람료': '5000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '세월의 장터를 큰 주제로 ＂1층-겨울, 2층-가을, 3층-여름, 4층-봄＂ T18테마로 구성, 곡식을 보관하던 항아리, 소쿠리, 바가지 등 각종 생활용기와 가마솥이 걸린 부뚜막, 절구, 전통혼례 복장, 꼭두각시 등 전통 민속품들을 전시',
#   '교통안내정보': '',
#   '관리기관전화번호': '062-222-6668',
#   '관리기관명': '비움박물관',
#   '데이터기준일자': '2022-01-10',
#   '제공기관코드': '3590000',
#   '제공기관명': '광주광역시 동구'},
#  {'시설명': '조선대학교미술관',
#   '박물관미술관구분': '대학',
#   '소재지도로명주소': '광주광역시 동구 필문대로 309(서석동,조선대학교)',
#   '소재지지번주소': '',
#   '위도': '35.146003',
#   '경도': '126.934363',
#   '운영기관전화번호': '062-230-7832',
#   '운영기관명': '조선대학교',
#   '운영홈페이지': 'https://blog.naver.com/cuma7832',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '토+일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '대학미술관으로써, 동문출신들의 작품을 중심으로 전시와 연구 보존 및 현대미술의 실험 현장을 지향함',
#   '교통안내정보': '',
#   '관리기관전화번호': '062-230-7832',
#   '관리기관명': '조선대학교',
#   '데이터기준일자': '2022-01-10',
#   '제공기관코드': '3590000',
#   '제공기관명': '광주광역시 동구'},
#  {'시설명': '의재미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '광주광역시 동구 증심사길 155(운림동)',
#   '소재지지번주소': '',
#   '위도': '35.12937059',
#   '경도': '126.967392',
#   '운영기관전화번호': '062-222-3040',
#   '운영기관명': '의재문화재단',
#   '운영홈페이지': 'http://www.uijae.org/',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:30',
#   '평일관람종료시각': '05:30',
#   '공휴일관람시작시각': '09:30',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '월',
#   '어른관람료': '2000',
#   '청소년관람료': '1000',
#   '어린이관람료': '0',
#   '관람료기타정보': '군인 1000원',
#   '박물관미술관소개': '의재미술관은 의재 허백련(毅齋 許百鍊) 선생을 기념하기 위해 건립된 미술관입니다.',
#   '교통안내정보': '',
#   '관리기관전화번호': '062-222-3040',
#   '관리기관명': '의재문화재단',
#   '데이터기준일자': '2022-01-10',
#   '제공기관코드': '3590000',
#   '제공기관명': '광주광역시 동구'},
#  {'시설명': '우제길미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '광주광역시 동구 의재로 140-6(운림동)',
#   '소재지지번주소': '',
#   '위도': '35.131806',
#   '경도': '126.943042',
#   '운영기관전화번호': '062-224-6601',
#   '운영기관명': '우제길미술관',
#   '운영홈페이지': 'http://www.wooart.co.kr/',
#   '편의시설정보': '',
#   '평일관람시작시각': '11:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '3000',
#   '청소년관람료': '3000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '군인 1000원',
#   '박물관미술관소개': '대학 미술관으로써, 동문출신들의 작품을 중심으로 전시와 연구, 보존',
#   '교통안내정보': '',
#   '관리기관전화번호': '062-224-6601',
#   '관리기관명': '우제길미술관',
#   '데이터기준일자': '2022-01-10',
#   '제공기관코드': '3590000',
#   '제공기관명': '광주광역시 동구'},
#  {'시설명': '무등현대미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '광주광역시 동구 증심사길 9(운림동)',
#   '소재지지번주소': '',
#   '위도': '35.134183',
#   '경도': '126.953723',
#   '운영기관전화번호': '062-223-6677',
#   '운영기관명': '무등현대미술관',
#   '운영홈페이지': 'http://www.mdmoca.co.kr',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '12:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '2000',
#   '청소년관람료': '1000',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '미술관의 명칭에 걸맞게 현대 미술 전시회를 꾸준히 개최하는 것은 물론 500여 점의 소장품을 중심으로 한 상설전시관을 운영',
#   '교통안내정보': '',
#   '관리기관전화번호': '062-223-6677',
#   '관리기관명': '무등현대미술관',
#   '데이터기준일자': '2022-01-10',
#   '제공기관코드': '3590000',
#   '제공기관명': '광주광역시 동구'},
#  {'시설명': '국윤미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '광주광역시 동구 의재로 82(소태동)',
#   '소재지지번주소': '',
#   '위도': '35.131896',
#   '경도': '126.936533',
#   '운영기관전화번호': '062-232-7335',
#   '운영기관명': '국윤미술관',
#   '운영홈페이지': 'http://cafe.daum.net/yywol',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '젊은 작가에서 중견, 원로 작가의 기획전과 초대전 중심으로 전시',
#   '교통안내정보': '',
#   '관리기관전화번호': '062-232-7335',
#   '관리기관명': '국윤미술관',
#   '데이터기준일자': '2022-01-10',
#   '제공기관코드': '3590000',
#   '제공기관명': '광주광역시 동구'},
#  {'시설명': '은암미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '광주광역시 동구 서석로 85번길8-12(대의동)',
#   '소재지지번주소': '',
#   '위도': '35.150012',
#   '경도': '126.920655',
#   '운영기관전화번호': '062-231-5299',
#   '운영기관명': '(사)동아시아미술교류협회운영',
#   '운영홈페이지': 'http://www.eunam.org',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '신진작가 발굴과 작고한 작가들의 작품전시, 기획전과 초대전 중심으로 운영하고 있으며, 국립아시아문화전당과 인접하여 미술인들 뿐만 아니라 시민의 소통장 역할을 하고 있음',
#   '교통안내정보': '',
#   '관리기관전화번호': '062-231-5299',
#   '관리기관명': '은암미술관',
#   '데이터기준일자': '2022-01-10',
#   '제공기관코드': '3590000',
#   '제공기관명': '광주광역시 동구'},
#  {'시설명': '성곡미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '서울특별시 종로구 경희궁길 42',
#   '소재지지번주소': '',
#   '위도': '37.57350943',
#   '경도': '126.969703',
#   '운영기관전화번호': '02-737-7650',
#   '운영기관명': '성곡미술관',
#   '운영홈페이지': 'http://www.sungkokmuseum.org/',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월, 설날연휴, 추석연휴',
#   '어른관람료': '7000',
#   '청소년관람료': '50000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '전시마다 상이',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-737-7650',
#   '관리기관명': '성곡미술관',
#   '데이터기준일자': '2021-07-06',
#   '제공기관코드': '3000000',
#   '제공기관명': '서울특별시 종로구'},
#  {'시설명': '주안미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '광주광역시 동구 제봉로 197(대인동)',
#   '소재지지번주소': '',
#   '위도': '35.153376',
#   '경도': '126.9156606',
#   '운영기관전화번호': '062-222-2083',
#   '운영기관명': '주안미술관',
#   '운영홈페이지': 'https://www.facebook.com/juanmoa14',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:30',
#   '평일관람종료시각': '19:00',
#   '공휴일관람시작시각': '09:30',
#   '공휴일관람종료시각': '19:00',
#   '휴관정보': '월',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '주안미술관은 대인예술시장, 예술의 거리, 아시아문화전당에 인접한 위치에 있어 접근성이 용이한 이점을 갖고 있다. 이러한 지리적 이점을 활용하여 젊은 작가들을 후원 및 양성하고 지역민과 예술가의 소통의 장이 될 수 있는 든든한 조력자로써 시민들의 삶의 질 향상에 이바지',
#   '교통안내정보': '',
#   '관리기관전화번호': '062-222-2083',
#   '관리기관명': '주안미술관',
#   '데이터기준일자': '2022-01-10',
#   '제공기관코드': '3590000',
#   '제공기관명': '광주광역시 동구'},
#  {'시설명': '강원랜드뿌리관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '강원도 정선군 사북읍 삼삼길 33',
#   '소재지지번주소': '강원도 정선군 사북읍 사북리 381-5',
#   '위도': '37.224552',
#   '경도': '128.815816',
#   '운영기관전화번호': '033-592-0103',
#   '운영기관명': '(재)3.3기념사업회',
#   '운영홈페이지': '',
#   '편의시설정보': '상설전시실+교육관+음악실+다목적실+화실+영상관+야외상설무대+뿌리공원',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '탄광마을의 역사와 문화 관련 전시',
#   '교통안내정보': '',
#   '관리기관전화번호': '033-560-2549',
#   '관리기관명': '강원도 정선군청',
#   '데이터기준일자': '2022-06-13',
#   '제공기관코드': '4290000',
#   '제공기관명': '강원도 정선군'},
#  {'시설명': '아라리인형의집 인형극박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '강원도 정선군 북평면 명주내길 43-1',
#   '소재지지번주소': '강원도 정선군 북평면 나전리 149',
#   '위도': '37.43807911',
#   '경도': '128.6469695',
#   '운영기관전화번호': '033-563-9667',
#   '운영기관명': '아라리인형의집',
# ...
#   '관람료기타정보': '특별전시입장료-일반(12000)+특별전시입장료-미취학(5000)+특별전시입장료-유치원+초등학생(6000)+특별전시입장료-청소년 (6000)+특별전시입장료-19~25세 (8000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-709-5114',
#   '관리기관명': '아모레퍼시픽미술관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '아트선재센터',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '서울특별시 종로구 율곡로3길 87',
#   '소재지지번주소': '',
#   '위도': '37.57946209',
#   '경도': '126.9818412',
#   '운영기관전화번호': '02-733-8949',
#   '운영기관명': '아트선재센터',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '12:00',
#   '평일관람종료시각': '19:00',
#   '공휴일관람시작시각': '12:00',
#   '공휴일관람종료시각': '19:00',
#   '휴관정보': '월+1월 1일+설 연휴+추석 연휴',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '특별전시입장료-일반(5000)+특별전시입장료-유치원+초등학생(3000)+특별전시입장료-청소년 (3000)+특별전시입장료-19~25세 (3000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-733-8949',
#   '관리기관명': '아트선재센터',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '아트센터나비미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '서울특별시 종로구 종로 26(서린동)',
#   '소재지지번주소': '',
#   '위도': '37.56969128',
#   '경도': '126.9803037',
#   '운영기관전화번호': '02-2121-1031',
#   '운영기관명': '아트센터나비미술관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '11:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '토+일+공휴일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-2121-0931',
#   '관리기관명': '아트센터나비미술관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '예술의전당 서울서예박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '서울특별시 서초구 남부순환로2406(서초동 700번지) 예술의전당내',
#   '소재지지번주소': '',
#   '위도': '37.48024074',
#   '경도': '127.0142139',
#   '운영기관전화번호': '02-580-1300',
#   '운영기관명': '예술의 전당',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '11:00',
#   '평일관람종료시각': '20:00',
#   '공휴일관람시작시각': '11:00',
#   '공휴일관람종료시각': '20:00',
#   '휴관정보': '월',
#   '어른관람료': '5000',
#   '청소년관람료': '3000',
#   '어린이관람료': '3000',
#   '관람료기타정보': '특별전시입장료-일반(5000)+특별전시입장료-유치원+초등학생(3000)+특별전시입장료-청소년 (3000)+특별전시입장료-19~25세 (5000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-580-1655',
#   '관리기관명': '예술의전당 서울서예박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '예술의전당 한가람디자인미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '서울특별시 서초구 남부순환로 2406',
#   '소재지지번주소': '',
#   '위도': '37.48024074',
#   '경도': '127.0142139',
#   '운영기관전화번호': '02-580-1300',
#   '운영기관명': '예술의전당',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '11:00',
#   '평일관람종료시각': '19:00',
#   '공휴일관람시작시각': '11:00',
#   '공휴일관람종료시각': '20:00',
#   '휴관정보': '마지막 주 월',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-580-1300',
#   '관리기관명': '예술의전당 한가람디자인미술관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '예술의전당 한가람미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '서울특별시 서초구 남부순환로 2406',
#   '소재지지번주소': '',
#   '위도': '37.48024074',
#   '경도': '127.0142139',
#   '운영기관전화번호': '02-580-1300',
#   '운영기관명': '예술의전당',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '11:00',
#   '평일관람종료시각': '19:00',
#   '공휴일관람시작시각': '11:00',
#   '공휴일관람종료시각': '20:00',
#   '휴관정보': '마지막 주 월',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-580-1300',
#   '관리기관명': '예술의전당 한가람미술관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '유리지공예관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '서울특별시 서초구 중앙로 555',
#   '소재지지번주소': '',
#   '위도': '37.45775892',
#   '경도': '127.012356',
#   '운영기관전화번호': '02-578-6663',
#   '운영기관명': '유리지공예관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '11:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '월+공휴일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-578-6663',
#   '관리기관명': '유리지공예관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '일민미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '서울특별시 종로구 세종대로 152',
#   '소재지지번주소': '',
#   '위도': '37.56986758',
#   '경도': '126.9776553',
#   '운영기관전화번호': '02-2020-2050',
#   '운영기관명': '(재)일민문화재단',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '11:00',
#   '평일관람종료시각': '19:00',
#   '공휴일관람시작시각': '11:00',
#   '공휴일관람종료시각': '19:00',
#   '휴관정보': '월+설 당일+추석 당일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '특별전시입장료-일반(6000)+특별전시입장료-유치원+초등학생(4500)+특별전시입장료-청소년 (4500)+특별전시입장료-19~25세 (4500)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-2020-2050',
#   '관리기관명': '일민미술관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '자하미술관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '서울특별시 종로구 창의문로5가길46',
#   '소재지지번주소': '',
#   '위도': '37.58937855',
#   '경도': '126.9603079',
#   '운영기관전화번호': '02-395-3222',
#   '운영기관명': '자하미술관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '2000',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '특별전시입장료-일반(5000) 특별전시입장료-19~25세 (3000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-395-3222',
#   '관리기관명': '자하미술관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '헬로키티아일랜드',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '제주특별자치도 서귀포시 안덕면 한창로 340',
#   '소재지지번주소': '',
#   '위도': '33.29009955',
#   '경도': '126.3520811',
#   '운영기관전화번호': '064-792-6114',
#   '운영기관명': '헬로키티아일랜드',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '연중무휴',
#   '어른관람료': '14000',
#   '청소년관람료': '13000',
#   '어린이관람료': '11000',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '064-792-6114',
#   '관리기관명': '헬로키티아일랜드',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '휴애리',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '제주특별자치도 서귀포시 남원읍 신례동로 256',
#   '소재지지번주소': '',
#   '위도': '33.30853475',
#   '경도': '126.6343808',
#   '운영기관전화번호': '064-732-2114',
#   '운영기관명': '휴애리',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '연중무휴',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '064-732-2114',
#   '관리기관명': '휴애리',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': 'SOS박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '제주특별자치도 서귀포시 월드컵로 31(법환동)',
#   '소재지지번주소': '',
#   '위도': '33.24706746',
#   '경도': '126.5073626',
#   '운영기관전화번호': '064-739-7707',
#   '운영기관명': '피오디코리아㈜',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '12000',
#   '청소년관람료': '10000',
#   '어린이관람료': '8000',
#   '관람료기타정보': '특별전시입장료-일반(12000)+특별전시입장료-유치원+초등학생(8000)+특별전시입장료-청소년 (10000)+특별전시입장료-19~25세 (12000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '064-739-7707',
#   '관리기관명': 'SOS박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '닥종이 인형 전시관(휴관)',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '제주특별자치도 서귀포시 월드컵로 33(법환동)',
#   '소재지지번주소': '',
#   '위도': '33.24621937',
#   '경도': '126.5092753',
#   '운영기관전화번호': '064-739-3906',
#   '운영기관명': '닥종이 인형 전시관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '23:59',
#   '휴관정보': '(* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '064-739-3906',
#   '관리기관명': '닥종이 인형 전시관(휴관)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '신영제주영화박물관(휴관)',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '제주특별자치도 서귀포시 남원읍 태위로 536',
#   '소재지지번주소': '',
#   '위도': '33.27515993',
#   '경도': '126.7082084',
#   '운영기관전화번호': '064-764-0002',
#   '운영기관명': '제주에코빌리지',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '연중무휴',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '064-764-0002',
#   '관리기관명': '신영제주영화박물관(휴관)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '제주화석박물관',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '제주특별자치도 서귀포시 표선면 하천로 11',
#   '소재지지번주소': '',
#   '위도': '33.343744',
#   '경도': '126.8433207',
#   '운영기관전화번호': '064-787-7831',
#   '운영기관명': '보석앤화석박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '23:59',
#   '휴관정보': '(* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '064-787-7831',
#   '관리기관명': '보석앤화석박물관(휴관)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '퍼피월드(휴관)',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '제주특별자치도 제주시 애월읍 평화로 2157',
#   '소재지지번주소': '',
#   '위도': '33.41314039',
#   '경도': '126.3927855',
#   '운영기관전화번호': '064-799-7272',
#   '운영기관명': '파파월드',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '23:59',
#   '휴관정보': '(* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '064-799-7272',
#   '관리기관명': '파파월드(휴관)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '타임파크(휴관)',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '제주특별자치도 제주시 한경면 녹차분재로 639-7',
#   '소재지지번주소': '',
#   '위도': '33.324067',
#   '경도': '126.2586797',
#   '운영기관전화번호': '000-0000-0000',
#   '운영기관명': '타임파크',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '23:59',
#   '휴관정보': '(* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '000-0000-0000',
#   '관리기관명': '타임파크(휴관)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '탐라신화공원(휴관)',
#   '박물관미술관구분': '사립',
#   '소재지도로명주소': '제주특별자치도 제주시 조천읍 선교로 474',
#   '소재지지번주소': '',
#   '위도': '33.4630261',
#   '경도': '126.7092086',
#   '운영기관전화번호': '000-0000-0000',
#   '운영기관명': '탐라신화공원',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '00:00',
#   '평일관람종료시각': '23:59',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '23:59',
#   '휴관정보': '(* 관람시각 정보 없음. 필요 시 기관으로 확인 요망)',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '000-0000-0000',
#   '관리기관명': '탐라신화공원(휴관)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '제주대학교박물관',
#   '박물관미술관구분': '대학',
#   '소재지도로명주소': '제주특별자치도 제주시 제주대학로 102(아라일동)',
#   '소재지지번주소': '',
#   '위도': '33.45723698',
#   '경도': '126.5642939',
#   '운영기관전화번호': '064-754-2241',
#   '운영기관명': '제주대학교박물관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '17:00',
#   '공휴일관람시작시각': '00:00',
#   '공휴일관람종료시각': '00:00',
#   '휴관정보': '공휴일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '064-754-2241',
#   '관리기관명': '제주대학교박물관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '국립현대미술관(과천)',
#   '박물관미술관구분': '국립',
#   '소재지도로명주소': '경기도 과천시 광명로 313(막계동)',
#   '소재지지번주소': '',
#   '위도': '37.431037',
#   '경도': '127.0199299',
#   '운영기관전화번호': '02-2188-6114',
#   '운영기관명': '국립현대미술관(과천관)',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월(단 월요일이 공휴일인 경우 당일은 개관하고 그 다음 첫번째 평일에 휴관)+1월 1일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-2188-6114',
#   '관리기관명': '국립현대미술관(과천)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '국립현대미술관(서울)',
#   '박물관미술관구분': '국립',
#   '소재지도로명주소': '서울특별시 종로구 삼청로 30(소격동)',
#   '소재지지번주소': '',
#   '위도': '37.57862803',
#   '경도': '126.980088',
#   '운영기관전화번호': '02-3701-9500',
#   '운영기관명': '국립현대미술관(서울관)',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '1월 1일+설 당일+추석 당일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '특별전시입장료-일반(4000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-3701-9500',
#   '관리기관명': '국립현대미술관(서울)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '국립현대미술관(덕수궁)',
#   '박물관미술관구분': '국립',
#   '소재지도로명주소': '서울특별시 중구 세종대로 99(정동)',
#   '소재지지번주소': '',
#   '위도': '37.56616815',
#   '경도': '126.9739838',
#   '운영기관전화번호': '02-2022-0600',
#   '운영기관명': '국립현대미술관(덕수궁관)',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '19:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '19:00',
#   '휴관정보': '월(단 월요일이 공휴일인 경우 당일은 개관하고 그 다음 첫번째 평일에 휴관)+1월 1일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-2022-0600',
#   '관리기관명': '국립현대미술관(덕수궁)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '국립현대미술관 미술품수장센터(청주)',
#   '박물관미술관구분': '국립',
#   '소재지도로명주소': '충청북도 청주시 청원구 상당로 314(내덕동)',
#   '소재지지번주소': '',
#   '위도': '36.65619563',
#   '경도': '127.4923824',
#   '운영기관전화번호': '043-261-1400',
#   '운영기관명': '국립현대미술관 미술품수장센터 (청주관)',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월+1월 1일+설 당일+추석 당일',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '043-261-1400',
#   '관리기관명': '국립현대미술관 미술품수장센터(청주)',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '겸재정선미술관',
#   '박물관미술관구분': '공립',
#   '소재지도로명주소': '서울특별시 강서구 양천로47길 36',
#   '소재지지번주소': '',
#   '위도': '37.57222423',
#   '경도': '126.8384111',
#   '운영기관전화번호': '02-2659-2206',
#   '운영기관명': '강서문화원',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '17:00',
#   '휴관정보': '월+1월 1일+설 당일+추석 당일',
#   '어른관람료': '1000',
#   '청소년관람료': '500',
#   '어린이관람료': '500',
#   '관람료기타정보': '특별전시입장료-일반(1000)+특별전시입장료-유치원+초등학생(500)+특별전시입장료-청소년 (500)+특별전시입장료-19~25세 (1000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-2600-6154',
#   '관리기관명': '겸재정선미술관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '남서울미술관',
#   '박물관미술관구분': '공립',
#   '소재지도로명주소': '서울특별시 관악구 남부순환로 2076(남현동)',
#   '소재지지번주소': '',
#   '위도': '37.47605354',
#   '경도': '126.9794659',
#   '운영기관전화번호': '02-598-6245',
#   '운영기관명': '서울시립미술관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '20:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '(* 향후 업데이트 예정. 필요 시 기관으로 문의 요망)',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-598-6245',
#   '관리기관명': '남서울미술관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '서울시립미술관',
#   '박물관미술관구분': '공립',
#   '소재지도로명주소': '서울특별시 중구 덕수궁길 61(서소문동 37)',
#   '소재지지번주소': '',
#   '위도': '37.5641076',
#   '경도': '126.9736993',
#   '운영기관전화번호': '02-2124-8800',
#   '운영기관명': '서울시립미술관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '10:00',
#   '평일관람종료시각': '20:00',
#   '공휴일관람시작시각': '10:00',
#   '공휴일관람종료시각': '19:00',
#   '휴관정보': '(* 향후 업데이트 예정. 필요 시 기관으로 문의 요망)',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-2124-8800',
#   '관리기관명': '서울시립미술관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  {'시설명': '성북구립미술관',
#   '박물관미술관구분': '공립',
#   '소재지도로명주소': '서울특별시 성북구 성북로 134',
#   '소재지지번주소': '',
#   '위도': '37.59483792',
#   '경도': '126.9948864',
#   '운영기관전화번호': '02-6925-5011',
#   '운영기관명': '성북구립미술관',
#   '운영홈페이지': '',
#   '편의시설정보': '',
#   '평일관람시작시각': '09:00',
#   '평일관람종료시각': '18:00',
#   '공휴일관람시작시각': '09:00',
#   '공휴일관람종료시각': '18:00',
#   '휴관정보': '월',
#   '어른관람료': '0',
#   '청소년관람료': '0',
#   '어린이관람료': '0',
#   '관람료기타정보': '특별전시입장료-일반(2000)+특별전시입장료-청소년 (1000)+특별전시입장료-19~25세 (2000)',
#   '박물관미술관소개': '',
#   '교통안내정보': '',
#   '관리기관전화번호': '02-6925-5011',
#   '관리기관명': '성북구립미술관',
#   '데이터기준일자': '2022-06-16',
#   '제공기관코드': '1371000',
#   '제공기관명': '문화체육관광부'},
#  ...]

# %%
df_target = pd.DataFrame(json_data['records'])

# %%
# 1-1
import pandas as pd

check_01_01(df_target)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 10 / 100

# %%
df_target.head(2)
# Out:
#          시설명 박물관미술관구분              소재지도로명주소 소재지지번주소           위도           경도  \
# 0    풀짚공예박물관       사립   경기도 광주시 오포읍 문형산길 76          37.36419778  127.1651063
# 1  프라움 악기박물관       사립  경기도 남양주시 와부읍 경강로 756          37.56850845  127.2270492
#
#        운영기관전화번호     운영기관명 운영홈페이지 편의시설정보  ... 청소년관람료 어린이관람료  \
# 0  031-717-4538   풀짚공예박물관                ...   1500   1500
# 1  031-521-6043  프라움악기박물관                ...   4000   3000
#
#                                              관람료기타정보 박물관미술관소개 교통안내정보  \
# 0  특별전시입장료-일반(3000)+특별전시입장료-미취학(1500)+특별전시입장료-유치원...
# 1
#
#        관리기관전화번호      관리기관명     데이터기준일자   제공기관코드    제공기관명
# 0  031-717-4538    풀짚공예박물관  2022-06-16  1371000  문화체육관광부
# 1  031-521-6043  프라움 악기박물관  2022-06-16  1371000  문화체육관광부
#
# [2 rows x 26 columns]

# %% [markdown]
# ## 2단계: DataFrame 전처리 01 - 기초
# ***

# %% [markdown]
# ### 문제 2-1) 기초 전처리 01 (5점)
# - 1단계의 DataFrame(df_target)을 아래의 조건에 맞게 변경하세요.
# <br></br>
#     - 해당 json_data의 null값은 ""로 구성되어 df_target.info() 또는 df_target.isna() 등을 이용하여 null값을 확인할 경우 null값이 없다고 나오게 됩니다. 이에 이 Data를 제대로 확인하기 위해서 "" 대신에 Null값을 넣으려 합니다.
# <br></br>
# <br></br>
#     - 조건1: ""(또는 '')는 띄어쓰기 없이 쌍따옴표(혹은 따옴표)로만 구성됩니다.
# <br></br>
#     - 조건2: ""(또는 '')를 null값(None)으로 바꾸세요.
# <br></br>
#     - 조건3: Index 또는 순서(order)는 변경하지 마세요.
# <br></br>
#     - 조건4: 'df_target' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_target)를 check_02_01 함수에 입력하여 채점하세요.

# %%
import numpy as np

# %%
# 조건 1, 2, 3, 4
df_target = df_target.replace('', np.nan)

# %%
# 2-1


check_02_01(df_target)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 15 / 100

# %%
df_target.head(2)
# Out:
#          시설명 박물관미술관구분              소재지도로명주소 소재지지번주소           위도           경도  \
# 0    풀짚공예박물관       사립   경기도 광주시 오포읍 문형산길 76     NaN  37.36419778  127.1651063
# 1  프라움 악기박물관       사립  경기도 남양주시 와부읍 경강로 756     NaN  37.56850845  127.2270492
#
#        운영기관전화번호     운영기관명 운영홈페이지 편의시설정보  ... 청소년관람료 어린이관람료  \
# 0  031-717-4538   풀짚공예박물관    NaN    NaN  ...   1500   1500
# 1  031-521-6043  프라움악기박물관    NaN    NaN  ...   4000   3000
#
#                                              관람료기타정보 박물관미술관소개 교통안내정보  \
# 0  특별전시입장료-일반(3000)+특별전시입장료-미취학(1500)+특별전시입장료-유치원...      NaN    NaN
# 1                                                NaN      NaN    NaN
#
#        관리기관전화번호      관리기관명     데이터기준일자   제공기관코드    제공기관명
# 0  031-717-4538    풀짚공예박물관  2022-06-16  1371000  문화체육관광부
# 1  031-521-6043  프라움 악기박물관  2022-06-16  1371000  문화체육관광부
#
# [2 rows x 26 columns]

# %% [markdown]
# ### 문제 2-2) 기초 전처리 02 (5점)
# - 2-1의 DataFrame(df_target)을 아래의 조건에 맞게 변경하세요.
# <br></br>
#     - json Data를 Pandas DataFrame으로 만들면서 수치형 데이터들이 string으로 인식되었습니다. 이를 변경하려고 합니다.
# <br></br>
# <br></br>
#     - 조건1: 아래 type_int_col의 Column(열) Data를 정수(int)형 Data로 변경하세요.
# <br></br>
#     - 조건2: 아래 type_float_col의 Column(열) Data를 실수(float)형 Data로 변경하세요.
# <br></br>
#     - 조건3: 변경할 Data에 Null값이 있다면, 0으로 채우세요.
# <br></br>
#     - 조건4: Index 또는 순서(order)는 변경하지 마세요.
# <br></br>
#     - 조건5: 'df_target' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_target)를 check_02_02 함수에 입력하여 채점하세요.

# %%
df1 = df_target.copy()

# %%
type_int_col = ['어른관람료', '청소년관람료', '어린이관람료']
type_float_col = ['위도', '경도']

# %%
df1[type_int_col] = df1[type_int_col].fillna(0)
df1[type_float_col] = df1[type_float_col].fillna(0)

# %%
# 조건 1, 2
df1[type_int_col] = df1[type_int_col].astype(int)
df1[type_float_col] = df1[type_float_col].astype(float)

# %%
df_target = df1

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117 entries, 0 to 2116
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시설명        2117 non-null   object
#  1   박물관미술관구분   2117 non-null   object
#  2   소재지도로명주소   2117 non-null   object
#  3   소재지지번주소    701 non-null    object
#  4   위도         2117 non-null   float64
#  5   경도         2117 non-null   float64
#  6   운영기관전화번호   2117 non-null   object
#  7   운영기관명      2117 non-null   object
#  8   운영홈페이지     804 non-null    object
#  9   편의시설정보     406 non-null    object
#  10  평일관람시작시각   2117 non-null   object
#  11  평일관람종료시각   2117 non-null   object
#  12  공휴일관람시작시각  2117 non-null   object
#  13  공휴일관람종료시각  2117 non-null   object
#  14  휴관정보       2117 non-null   object
#  15  어른관람료      2117 non-null   int32
#  16  청소년관람료     2117 non-null   int32
#  17  어린이관람료     2117 non-null   int32
#  18  관람료기타정보    726 non-null    object
#  19  박물관미술관소개   561 non-null    object
#  20  교통안내정보     417 non-null    object
#  21  관리기관전화번호   2117 non-null   object
#  22  관리기관명      2117 non-null   object
#  23  데이터기준일자    2117 non-null   object
#  24  제공기관코드     2117 non-null   object
#  25  제공기관명      2117 non-null   object
# dtypes: float64(2), int32(3), object(21)
# memory usage: 405.3+ KB

# %%
# 2-2
check_02_02(df_target)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 20 / 100

# %%
df_target.head(2)
# Out:
#          시설명 박물관미술관구분              소재지도로명주소 소재지지번주소         위도          경도  \
# 0    풀짚공예박물관       사립   경기도 광주시 오포읍 문형산길 76     NaN  37.364198  127.165106
# 1  프라움 악기박물관       사립  경기도 남양주시 와부읍 경강로 756     NaN  37.568508  127.227049
#
#        운영기관전화번호     운영기관명 운영홈페이지 편의시설정보  ... 청소년관람료 어린이관람료  \
# 0  031-717-4538   풀짚공예박물관    NaN    NaN  ...   1500   1500
# 1  031-521-6043  프라움악기박물관    NaN    NaN  ...   4000   3000
#
#                                              관람료기타정보 박물관미술관소개 교통안내정보  \
# 0  특별전시입장료-일반(3000)+특별전시입장료-미취학(1500)+특별전시입장료-유치원...      NaN    NaN
# 1                                                NaN      NaN    NaN
#
#        관리기관전화번호      관리기관명     데이터기준일자   제공기관코드    제공기관명
# 0  031-717-4538    풀짚공예박물관  2022-06-16  1371000  문화체육관광부
# 1  031-521-6043  프라움 악기박물관  2022-06-16  1371000  문화체육관광부
#
# [2 rows x 26 columns]

# %% [markdown]
# ### 문제 2-3) 기초 전처리 03 (5점)
# - 2-2의 DataFrame(df_target)을 아래의 조건에 맞게 변경하세요.
# <br></br>
#     - 분석과 상관 없는 Column(열)의 Data들을 삭제하여 Data의 가독성을 높이고자 합니다.
# <br></br>
# <br></br>
#     - 조건1: 아래 drop_col의 Column(열) Data를 삭제하세요.
# <br></br>
#     - 조건2: Index 또는 순서(order)는 변경하지 마세요.
# <br></br>
#     - 조건3: 'df_target' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_target)를 check_02_03 함수에 입력하여 채점하세요.

# %%
drop_cols = ['소재지지번주소', '위도', '경도', '운영기관전화번호','운영기관명', '운영홈페이지', '편의시설정보', '휴관정보', 
            '관람료기타정보', '박물관미술관소개', '교통안내정보', '관리기관전화번호', '관리기관명', '제공기관코드', '제공기관명']

# %%
df_target = df_target.drop(columns=drop_cols, axis=1)
df_target.head(2)
# Out:
#          시설명 박물관미술관구분              소재지도로명주소 평일관람시작시각 평일관람종료시각 공휴일관람시작시각  \
# 0    풀짚공예박물관       사립   경기도 광주시 오포읍 문형산길 76    09:30    18:00     10:00
# 1  프라움 악기박물관       사립  경기도 남양주시 와부읍 경강로 756    00:00    23:59     00:00
#
#   공휴일관람종료시각  어른관람료  청소년관람료  어린이관람료     데이터기준일자
# 0     18:00   3000    1500    1500  2022-06-16
# 1     23:59   5000    4000    3000  2022-06-16

# %%
# 2-3


check_02_03(df_target)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 70 / 100

# %%
df_target.head(2)
# Out:
#          시설명 박물관미술관구분              소재지도로명주소 평일관람시작시각 평일관람종료시각 공휴일관람시작시각  \
# 0    풀짚공예박물관       사립   경기도 광주시 오포읍 문형산길 76    09:30    18:00     10:00
# 1  프라움 악기박물관       사립  경기도 남양주시 와부읍 경강로 756    00:00    23:59     00:00
#
#   공휴일관람종료시각  어른관람료  청소년관람료  어린이관람료     데이터기준일자
# 0     18:00   3000    1500    1500  2022-06-16
# 1     23:59   5000    4000    3000  2022-06-16

# %% [markdown]
# ### 문제 2-4) 기초 전처리 04 (5점)
# - 2-3의 DataFrame(df_target)을 아래의 조건에 맞게 변경하세요.
# <br></br>
#     - 어른, 청소년, 어린이 관람료가 이상한 경우, 해당 row(행) data 자체가 이상하다고 판단하여 삭제하고자 합니다.
# <br></br>
# <br></br>
#     - 조건1: 관람료와 관련된 Column(열)은 위에서 정의한 type_int_col 입니다.
# <br></br>
#     - 조건2: 관람료가 10원 단위로 나누어 떨어지지 않는 경우 이상치로 판단합니다. 해당 row(행)를 삭제하세요.
# <br></br>
#     - 조건3: 관람료가 100000원(십만원) 이상인 경우 이상치로 판단합니다. 해당 row(행)를 삭제하세요.
# <br></br>
#     - 조건4: Index 또는 순서(order)는 변경하지 마세요.
# <br></br>
#     - 조건5: 'df_target' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_target)를 check_02_04 함수에 입력하여 채점하세요.

# %%
df3 = df_target.copy()

# %%
df3[type_int_col] = df3[type_int_col][df3[type_int_col] % 10 == 0]
df3[type_int_col] = df3[type_int_col][df3[type_int_col] <= 100000]
df3 = df3.dropna(axis=0)
df3[type_int_col] = df3[type_int_col].astype(int)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2111 entries, 0 to 2116
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시설명        2111 non-null   object
#  1   박물관미술관구분   2111 non-null   object
#  2   소재지도로명주소   2111 non-null   object
#  3   평일관람시작시각   2111 non-null   object
#  4   평일관람종료시각   2111 non-null   object
#  5   공휴일관람시작시각  2111 non-null   object
#  6   공휴일관람종료시각  2111 non-null   object
#  7   어른관람료      2111 non-null   int32
#  8   청소년관람료     2111 non-null   int32
#  9   어린이관람료     2111 non-null   int32
#  10  데이터기준일자    2111 non-null   object
# dtypes: int32(3), object(8)
# memory usage: 173.2+ KB

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117 entries, 0 to 2116
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시설명        2117 non-null   object
#  1   박물관미술관구분   2117 non-null   object
#  2   소재지도로명주소   2117 non-null   object
#  3   평일관람시작시각   2117 non-null   object
#  4   평일관람종료시각   2117 non-null   object
#  5   공휴일관람시작시각  2117 non-null   object
#  6   공휴일관람종료시각  2117 non-null   object
#  7   어른관람료      2117 non-null   int32
#  8   청소년관람료     2117 non-null   int32
#  9   어린이관람료     2117 non-null   int32
#  10  데이터기준일자    2117 non-null   object
# dtypes: int32(3), object(8)
# memory usage: 157.2+ KB

# %%
df3.head(2)
# Out:
#          시설명 박물관미술관구분              소재지도로명주소 평일관람시작시각 평일관람종료시각 공휴일관람시작시각  \
# 0    풀짚공예박물관       사립   경기도 광주시 오포읍 문형산길 76    09:30    18:00     10:00
# 1  프라움 악기박물관       사립  경기도 남양주시 와부읍 경강로 756    00:00    23:59     00:00
#
#   공휴일관람종료시각  어른관람료  청소년관람료  어린이관람료     데이터기준일자
# 0     18:00   3000    1500    1500  2022-06-16
# 1     23:59   5000    4000    3000  2022-06-16

# %%
# 2-4
df_target = df3

check_02_04(df_target)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 70 / 100

# %%
df_target.head(2)
# Out:
#          시설명 박물관미술관구분              소재지도로명주소 평일관람시작시각 평일관람종료시각 공휴일관람시작시각  \
# 0    풀짚공예박물관       사립   경기도 광주시 오포읍 문형산길 76    09:30    18:00     10:00
# 1  프라움 악기박물관       사립  경기도 남양주시 와부읍 경강로 756    00:00    23:59     00:00
#
#   공휴일관람종료시각  어른관람료  청소년관람료  어린이관람료     데이터기준일자
# 0     18:00   3000    1500    1500  2022-06-16
# 1     23:59   5000    4000    3000  2022-06-16

# %% [markdown]
# ## 3단계: DataFrame 전처리 02 - 심화
# ***

# %% [markdown]
# ### 문제 3-1) 심화 전처리 01 (10점)
# - 2단계의 DataFrame(df_target)을 아래의 조건에 맞게 변경하세요.
# <br></br>
#     - 휴관중이거나 중복된 박물관/미술관의 data를 삭제하고자 합니다.
#         - 아래의 조건 이외에도 중복되는 data들이 있으나, 해당 Test에서는 아래 조건에 따른 중복 data만 삭제하여 진행합니다.
# <br></br>
# <br></br>
#     - 조건1: 시설명 Column(열) data에 '휴관'이라는 글자가 들어있으면 해당 row(행)은 삭제합니다.
# <br></br>
#     - 조건2: 시설명 Column(열) data가 중복되는 경우 해당 row(행)의 '데이터기준일자'가 최신인 data를 남기고 최신이 아닌 row(행)은 삭제합니다.
# <br></br>
#         - 만약, 시설명 Column(행)의 data가 중복되면서 가장 최신인 data가 두 개 이상인 경우, Index가 가장 낮은(예시: 495, 674 중 495) Index를 남기고, 높은 Index(예시: 495, 674 중 674)의 row(행) data를 삭제하세요.(낮은 인덱스가 더 최근 데이터라고 가정)
# <br></br>
#         - 예시: 아래 예시의 경우 데이터기준일자가 최신인 0번 index의 row(행)은 남기고 1338번 index의 row(행)은 삭제합니다.
# <br></br>
#         <img src="images/05-3-1-001.png" style="margin:auto" width=800/>
# <br></br>
#     - 조건3: 시설명 Column(열) data의 중복 여부는 시설명 Column(열) data의 띄어쓰기를 삭제한 값이 일치할 경우 중복된 박물관/미술관으로 판단합니다.
# <br></br>
#         - 예시: 아래 예시의 경우 시설명 Column(열) data의 띄어쓰기를 삭제할 경우 시설명 Column(열) data가 동일합니다. 이에 데이터기준일자가 최신인 6번 index의 row(행)은 남기고 1909번 index의 row(행)은 삭제합니다.
# <br></br>
#         <img src="images/05-3-1-002.png" style="margin:auto" width=800/>
# <br></br>
#     - 조건4: Index 또는 순서(order)는 변경하지 마세요.
#         - 문제를 풀기위해 순서를 변경하였다면, 다시 Index 순서로 정렬하세요
# <br></br>
#     - 조건5: 'df_target' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
#     - hint1: '데이터기준일자' Column(열)의 Data는 현재 string입니다. 대소비교가 가능한지 확인해보세요.
# <br></br>
#     - hint2: 조건2 관련하여, '시설명'과 '데이터기준일자'가 같은 data들이 존재합니다. Index를 확인하세요.
#         - '데이터기준일자' 기준으로 정렬시 주의하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_target)를 check_03_01 함수에 입력하여 채점하세요.

# %% [markdown]
# #### 방법1, 2 둘 중 하나 또는 그 외 본인만의 방법으로 작성하시면 됩니다 :)

# %%
df4 = df_target.copy()

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2111 entries, 0 to 2116
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시설명        2111 non-null   object
#  1   박물관미술관구분   2111 non-null   object
#  2   소재지도로명주소   2111 non-null   object
#  3   평일관람시작시각   2111 non-null   object
#  4   평일관람종료시각   2111 non-null   object
#  5   공휴일관람시작시각  2111 non-null   object
#  6   공휴일관람종료시각  2111 non-null   object
#  7   어른관람료      2111 non-null   int32
#  8   청소년관람료     2111 non-null   int32
#  9   어린이관람료     2111 non-null   int32
#  10  데이터기준일자    2111 non-null   object
# dtypes: int32(3), object(8)
# memory usage: 173.2+ KB

# %%
# 조건1
# 교집합 : A[A.isin(B)] / 차집합 : A[~A.isin(B)]
df4 = df4[~df4['시설명'].str.contains('휴관')]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1361 entries, 0 to 2112
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시설명        1361 non-null   object
#  1   박물관미술관구분   1361 non-null   object
#  2   소재지도로명주소   1361 non-null   object
#  3   평일관람시작시각   1361 non-null   object
#  4   평일관람종료시각   1361 non-null   object
#  5   공휴일관람시작시각  1361 non-null   object
#  6   공휴일관람종료시각  1361 non-null   object
#  7   어른관람료      1361 non-null   int32
#  8   청소년관람료     1361 non-null   int32
#  9   어린이관람료     1361 non-null   int32
#  10  데이터기준일자    1361 non-null   object
# dtypes: int32(3), object(8)
# memory usage: 111.6+ KB

# %%
# 조건 2,3, 4
df4['시설명'] = df4['시설명'].str.replace(' ','')
df4 = df4.sort_values(by='데이터기준일자', ascending=False)  # 시설명 열을 기준으로 내림차순 정렬
df4 = df4.drop_duplicates(subset='시설명', keep='first')  # 중복 제거, 마지막으로 나타난 행 남기기
df4 = df4.sort_index()
df4
# Out:
#              시설명 박물관미술관구분                      소재지도로명주소 평일관람시작시각 평일관람종료시각  \
# 0        풀짚공예박물관       사립           경기도 광주시 오포읍 문형산길 76    09:30    18:00
# 1       프라움악기박물관       사립          경기도 남양주시 와부읍 경강로 756    00:00    23:59
# 2        피노키오뮤지엄       사립          경기도 파주시 회동길 152(문발동)    10:30    18:30
# 3     한과문화박물관한가원       사립  경기도 포천시 영북면 산정호수로 322번길 26-9    10:00    18:00
# 4      한국근현대사박물관       사립      경기도 파주시 탄현면 헤이리마을길 59-85    09:30    18:00
# ...          ...      ...                           ...      ...      ...
# 2101       몽촌역사관       공립             서울특별시 송파구 올림픽로424    09:00    18:00
# 2103       롯데뮤지엄       사립            서울특별시 송파구 올림픽로 300    10:30    20:00
# 2107   서울우리소리박물관       공립              서울특별시 종로구 율곡로 96    09:00    19:00
# 2111      옥천골미술관       공립           전라북도 순창군 순창읍 남계로 81    10:00    18:00
# 2112      섬진강미술관       공립          전라북도 순창군 적성면 평남길 113    10:00    18:00
#
#      공휴일관람시작시각 공휴일관람종료시각  어른관람료  청소년관람료  어린이관람료     데이터기준일자
# 0        10:00     18:00   3000    1500    1500  2022-06-16
# 1        00:00     23:59   5000    4000    3000  2022-06-16
# 2        10:30     18:30   8000    8000    8000  2022-06-16
# 3        10:00     18:00   3000    1500    1500  2022-06-16
# 4        09:30     19:00   7000    5000    5000  2022-06-16
# ...        ...       ...    ...     ...     ...         ...
# 2101     09:00     18:00      0       0       0  2020-02-13
# 2103     10:30     20:00  13000   10000    7000  2020-02-13
# 2107     09:00     19:00      0       0       0  2021-07-06
# 2111     10:00     18:00      0       0       0  2021-09-30
# 2112     10:00     18:00      0       0       0  2021-09-30
#
# [1361 rows x 11 columns]

# %%
# 조건 5
df_target_temp = df4

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1361 entries, 0 to 2112
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시설명        1361 non-null   object
#  1   박물관미술관구분   1361 non-null   object
#  2   소재지도로명주소   1361 non-null   object
#  3   평일관람시작시각   1361 non-null   object
#  4   평일관람종료시각   1361 non-null   object
#  5   공휴일관람시작시각  1361 non-null   object
#  6   공휴일관람종료시각  1361 non-null   object
#  7   어른관람료      1361 non-null   int32
#  8   청소년관람료     1361 non-null   int32
#  9   어린이관람료     1361 non-null   int32
#  10  데이터기준일자    1361 non-null   object
# dtypes: int32(3), object(8)
# memory usage: 111.6+ KB

# %%
# 3-1

# 해당 문제에서는 데이터기준일자의 형식(년-월-일) 특성상 타입을 변경하지 않아도 정상적으로 대소비교 가능합니다..
# 따라서 아래 주석과 같이 format을 변경할 필요 없습니다.
# from datetime import date
# df_target.데이터기준일자 = df_target.데이터기준일자.apply(date.fromisoformat)

check_03_01(df_target_temp)
display(df_target_temp.head())

df_target = df_target_temp.copy()
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 70 / 100
#           시설명 박물관미술관구분                      소재지도로명주소 평일관람시작시각 평일관람종료시각  \
# 0     풀짚공예박물관       사립           경기도 광주시 오포읍 문형산길 76    09:30    18:00
# 1    프라움악기박물관       사립          경기도 남양주시 와부읍 경강로 756    00:00    23:59
# 2     피노키오뮤지엄       사립          경기도 파주시 회동길 152(문발동)    10:30    18:30
# 3  한과문화박물관한가원       사립  경기도 포천시 영북면 산정호수로 322번길 26-9    10:00    18:00
# 4   한국근현대사박물관       사립      경기도 파주시 탄현면 헤이리마을길 59-85    09:30    18:00
#
#   공휴일관람시작시각 공휴일관람종료시각  어른관람료  청소년관람료  어린이관람료     데이터기준일자  평일관람가능시간  공휴일관람가능시간  \
# 0     10:00     18:00   3000    1500    1500  2022-06-16       8.5        8.0
# 1     00:00     23:59   5000    4000    3000  2022-06-16      24.0       24.0
# 2     10:30     18:30   8000    8000    8000  2022-06-16       8.0        8.0
# 3     10:00     18:00   3000    1500    1500  2022-06-16       8.0        8.0
# 4     09:30     19:00   7000    5000    5000  2022-06-16       8.5        9.5
#
#     광역    기초                    상세
# 0  경기도   광주시           오포읍 문형산길 76
# 1  경기도  남양주시           와부읍 경강로 756
# 2  경기도   파주시          회동길 152(문발동)
# 3  경기도   포천시  영북면 산정호수로 322번길 26-9
# 4  경기도   파주시      탄현면 헤이리마을길 59-85

# %% [markdown]
# ### 문제 3-2) 심화 전처리 02 (10점)
# - 3-1의 DataFrame(df_target)을 아래의 조건에 맞게 변경하세요.
# <br></br>
#     - 평일과 공휴일에 박물관/미술관이 하루 중 몇시간이나 열려있는지를 알려주는 '관람가능시간'을 구하려고 합니다.
# <br></br>
# <br></br>
#     - 조건1: 평일의 관람가능시간은 '평일관람시작시각'부터 '평일관람종료시각'까지 입니다. '평일관람가능시간' Column(열)을 만들어 평일의 관람가능시간을 입력하세요.
# <br></br>
#     - 조건2: 공휴일의 관람가능시간은 '공휴일관람시작시각'부터 '공휴일관람종료시각'까지 입니다. '공휴일관람가능시간' Column(열)을 만들어 공휴일의 관람가능시간을 입력하세요.
# <br></br>
#     - 조건3: '평일관람가능시간'과 '공휴일관람가능시간'은 시간(hour) 단위 실수(float)로 표기합니다.
# <br></br>
#         - 관람가능시간이 8시간 30분인경우 8.5로 표기합니다.
#         - 관람가능시간이 23시간을 초과하는 경우 24시간으로 표기합니다.
#         - 평일 또는 공휴일의 관람시작시각과 관람종료시각이 모두 00:00(또는 0:00)인 경우 휴일로 판단하며, 관람가능시간은 0으로 입력합니다.
#         - 관람가능시간이 6시간 40분과 같이 무환소수(6.6666666666666......6666666667)로 표기될 경우 소숫점 셋째 자리에서 반올림하여 소숫점 둘째 자리까지 표기합니다.
# <br></br>
#         - 예시
# <br></br>
#         <img src="images/05-3-2-001.png" style="margin:auto" width=800/>
# <br></br>
#     - 조건4: Index 또는 순서(order)는 변경하지 마세요.
# <br></br>
#     - 조건5: 'df_target' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
#     - hint: 각 관람시작시각/관람종료시각의 Data Type은 string 입니다.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_target)를 check_03_02 함수에 입력하여 채점하세요.

# %% [markdown]
# #### 방법1, 2 둘 중 하나 또는 그 외 본인만의 방법으로 작성하시면 됩니다 :)

# %%
df5 = df_target.copy()

# %%
# 시간 형식을 datetime으로 변환
x1 = pd.to_datetime(df5['평일관람시작시각'], format='%H:%M')
x2 = pd.to_datetime(df5['평일관람종료시각'], format='%H:%M')
y1 = pd.to_datetime(df5['공휴일관람시작시각'], format='%H:%M')
y2 = pd.to_datetime(df5['공휴일관람종료시각'], format='%H:%M')

# %%
# 조건 1, 2, 3, 4
df5['평일관람가능시간'] = round((x2 - x1).dt.total_seconds() / 3600,2)
df5['공휴일관람가능시간'] = round((y2 - y1).dt.total_seconds() / 3600, 2)
df5.loc[df5['평일관람가능시간'] > 23, '평일관람가능시간'] = 24
df5.loc[df5['공휴일관람가능시간'] > 23, '공휴일관람가능시간'] = 24
# 조건 3 보완
df5['평일관람가능시간'] = df5['평일관람가능시간'].apply(lambda x: x + 24 if x < 0 else x)
df5['공휴일관람가능시간'] = df5['공휴일관람가능시간'].apply(lambda x: x + 24 if x < 0 else x)

# %%
df5.tail(2)
# Out:
#          시설명 박물관미술관구분              소재지도로명주소 평일관람시작시각 평일관람종료시각 공휴일관람시작시각  \
# 2111  옥천골미술관       공립   전라북도 순창군 순창읍 남계로 81    10:00    18:00     10:00
# 2112  섬진강미술관       공립  전라북도 순창군 적성면 평남길 113    10:00    18:00     10:00
#
#      공휴일관람종료시각  어른관람료  청소년관람료  어린이관람료     데이터기준일자  평일관람가능시간  공휴일관람가능시간    광역  \
# 2111     18:00      0       0       0  2021-09-30       8.0        8.0  전라북도
# 2112     18:00      0       0       0  2021-09-30       8.0        8.0  전라북도
#
#        기초           상세
# 2111  순창군   순창읍 남계로 81
# 2112  순창군  적성면 평남길 113

# %%
df_target_temp = df5

# %%
# 조건 5
df_target = df_target_temp.copy()

# %%
# 3-2
check_03_02(df_target_temp)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 70 / 100

# %% [markdown]
# ### 문제 3-3) 심화 전처리 03 (10점)
# - 3-2의 DataFrame(df_target)을 아래의 조건에 맞게 변경하세요.
# <br></br>
#     - '소재지도로명주소' Column(열)의 Data를 가공하여 광역자치단체-기초자치단체(행정시)-상세 주소로 구분하려고 합니다.
# <br></br>
# <br></br>
#     - 조건1: '소재재도로명주소' Column(열) data의 첫번째 단어는 언제나 광역자치단체명을 의미합니다. '광역' Column(열)을 만들어 해당 row(행) data의 광역자치단체명을 입력하세요.
#         - '세종특별시'는 현재 '세종특별자차시'로 명칭이 변경되었습니다. 이를 반영해주세요.
# <br></br>
#     - 조건2: '소재재도로명주소' Column(열) data의 두번째 단어는 대부분 기초자치단체명을 의미합니다. '기초' Column(열)을 만들어 해당 row(행) data의 기초자치단체명을 입력하세요.
#         - '제주특별자치도'의 경우 기초자치단체가 없으나, 행정시('제주시', '서귀포시')가 '소재재도로명주소' Column(열) data의 두번째 단어에 위치합니다. 행정시를 '기초' Column(열)에 입력하세요.
#         - '세종특별자치시'의 경우 기초자치단체가 없습니다. '세종특별자치시'의 경우 '기초' Column(열)에는 Null값(None)을 입력해주세요.
# <br></br>
#     - 조건3: '소재재도로명주소' Column(열) data에서 광역/기초자치단체(행정시포함)에 포함되지 않은 데이터는 '상세' Column(열)을 만들어 입력하세요.
# <br></br>
#         - 예시
# <br></br>
#         <img src="images/05-3-3-001.png" style="margin:auto" width=800/>
# <br></br>
#     - 조건4: '소재지도로명주소', '광역', '기초', '상세 Column(행)의 data는 해당 data의 앞-뒤로 띄어쓰기 등 공백이 없어야 합니다.
# <br></br>
#     - 조건5: Index 또는 순서(order)는 변경하지 마세요.
# <br></br>
#     - 조건6: 'df_target' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_target)를 check_03_03 함수에 입력하여 채점하세요.

# %% [markdown]
# #### 방법1, 2 둘 중 하나 또는 그 외 본인만의 방법으로 작성하시면 됩니다 :)

# %% [markdown]
# https://hleecaster.com/pandas-data-cleaning-2/

# %%
df6 = df_target.copy()

# %%
address = df6['소재지도로명주소'].str.split(' ')

# %%
address
# Out:
# 0                 [경기도, 광주시, 오포읍, 문형산길, 76]
# 1                [경기도, 남양주시, 와부읍, 경강로, 756]
# 2                 [경기도, 파주시, 회동길, 152(문발동)]
# 3       [경기도, 포천시, 영북면, 산정호수로, 322번길, 26-9]
# 4            [경기도, 파주시, 탄현면, 헤이리마을길, 59-85]
#                        ...
# 2101                  [서울특별시, 송파구, 올림픽로424]
# 2103                [서울특별시, 송파구, 올림픽로, 300]
# 2107                  [서울특별시, 종로구, 율곡로, 96]
# 2111              [전라북도, 순창군, 순창읍, 남계로, 81]
# 2112             [전라북도, 순창군, 적성면, 평남길, 113]
# Name: 소재지도로명주소, Length: 1361, dtype: object

# %% [markdown]
# 본인 코드
# ```
# # 조건 1 광역
# for idx, row in df6.iterrows():
#     if df6['소재지도로명주소'][idx][0] == '세종특별시':
#         df6.at[idx, '광역'] = '세종특별자차시'
#     else:
#         df6.at[idx, '광역'] = address[idx][0]
# ```
#
# startswith는 괄호안의 값으로 시작하는지 여부를 확인하는 코드임!!

# %%
for idx, row in df6.iterrows():
    df6.at[idx, '소재지도로명주소'] = df6.at[idx, '소재지도로명주소'].strip()

# %%
# 조건 1 광역
for idx, row in df6.iterrows():
    if df6['소재지도로명주소'][idx].startswith('세종특별시'):
        df6.at[idx, '광역'] = '세종특별자치시'
    elif df6['소재지도로명주소'][idx].startswith('세종특별자차시'):
        df6.at[idx, '광역'] = '세종특별자치시'   
    else:
        df6.at[idx, '광역'] = address[idx][0]

# %%
# 조건  2 기초
for idx, row in df6.iterrows():
    if df6['소재지도로명주소'][idx].startswith('세종특별자치시'):
        df6.at[idx, '기초'] = None
    elif df6['소재지도로명주소'][idx].startswith('세종특별시'):
        df6.at[idx, '기초'] = None
    else:
        df6.at[idx, '기초'] = address[idx][1]

# %%
# 조건  3 상세
result = ' '.join(address[1][2:])
result1 = ' '.join(address[1][1:])
for idx, row in df6.iterrows():
    if df6['소재지도로명주소'][idx].startswith('세종특별자치시'):
        df6.at[idx, '상세'] = result1
    elif df6['소재지도로명주소'][idx].startswith('세종특별시'):
        df6.at[idx, '상세'] = result1  
    else:
        result = ' '.join(address[idx][2:])
        df6.at[idx, '상세'] = result

# %%
len(address), address[1601][1:]
# Out:
# (1361, ['국세청로', '8-14'])

# %%
df6['광역'].unique()
# Out:
# array(['경기도', '광주광역시', '서울특별시', '전라북도', '강원도', '울산광역시', '충청남도', '세종특별자치시',
#        '대전광역시', '전라남도', '인천광역시', '대구광역시', '충청북도', '제주특별자치도', '경상남도',
#        '경상북도', '부산광역시'], dtype=object)

# %%
# 3-3
df_target_temp = df6
check_03_03(df_target_temp)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 70 / 100

# %%
display(df_target_temp.head())
# 조건 5
df_target = df_target_temp.copy()
# Out:
#           시설명 박물관미술관구분                      소재지도로명주소 평일관람시작시각 평일관람종료시각  \
# 0     풀짚공예박물관       사립           경기도 광주시 오포읍 문형산길 76    09:30    18:00
# 1    프라움악기박물관       사립          경기도 남양주시 와부읍 경강로 756    00:00    23:59
# 2     피노키오뮤지엄       사립          경기도 파주시 회동길 152(문발동)    10:30    18:30
# 3  한과문화박물관한가원       사립  경기도 포천시 영북면 산정호수로 322번길 26-9    10:00    18:00
# 4   한국근현대사박물관       사립      경기도 파주시 탄현면 헤이리마을길 59-85    09:30    18:00
#
#   공휴일관람시작시각 공휴일관람종료시각  어른관람료  청소년관람료  어린이관람료     데이터기준일자  평일관람가능시간  공휴일관람가능시간  \
# 0     10:00     18:00   3000    1500    1500  2022-06-16       8.5        8.0
# 1     00:00     23:59   5000    4000    3000  2022-06-16      24.0       24.0
# 2     10:30     18:30   8000    8000    8000  2022-06-16       8.0        8.0
# 3     10:00     18:00   3000    1500    1500  2022-06-16       8.0        8.0
# 4     09:30     19:00   7000    5000    5000  2022-06-16       8.5        9.5
#
#     광역    기초                    상세
# 0  경기도   광주시           오포읍 문형산길 76
# 1  경기도  남양주시           와부읍 경강로 756
# 2  경기도   파주시          회동길 152(문발동)
# 3  경기도   포천시  영북면 산정호수로 322번길 26-9
# 4  경기도   파주시      탄현면 헤이리마을길 59-85

# %% [markdown]
# ## 4단계: 원하는 정보 얻기
# ***

# %% [markdown]
# ### 문제 4-1) 원하는 정보 얻기 01 (10점)
# - 3단계의 DataFrame(df_target)을 이용하여 아래의 조건에 맞는 정보를 구하세요.
# <br></br>
#     - 광역자치단체별 박물관/미술관의 총 수를 확인하고자 합니다.
# <br></br>
# <br></br>
#     - 조건1: df_target의 '광역' Column(열)에 있는 광역자치단체 data를 이용하여 광역자치단체별 박물관/미술관의 총 수를 나타내주세요.
# <br></br>
#     - 조건2: 결과 DataFrame의 Index는 광역자치단체입니다. 광역자치단체의 우선순위는 아래 province_dict의 value(값)으로 제공합니다. Index의 순서를 광역자치단체의 우선순위에 따라 나열해주세요.
#         - 출처: [행정안전부](https://www.mois.go.kr/frt/sub/a04/localGovernment/screen.do)
# <br></br>
#     - 조건3: 결과 DataFrame의 박물관/미술관의 총 수를 나타내는 Column(열)의 이름은 '박물관미술관수' 입니다.
# <br></br>
#         - 예시: Index/Column
# <br></br>
#         <img src="images/05-4-1-001.png" style="margin:auto" width=200/>
# <br></br>
#     - 조건4: 'df_result' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_result)를 check_04_01 함수에 입력하여 채점하세요.

# %%
province_dict = {
    '서울특별시': 0,
    '부산광역시': 1,
    '대구광역시': 2,
    '인천광역시': 3,
    '광주광역시': 4,
    '대전광역시': 5,
    '울산광역시': 6,
    '세종특별자치시': 7,
    '경기도': 8,
    '강원도': 9,
    '충청북도': 10,
    '충청남도': 11,
    '전라북도': 12,
    '전라남도': 13,
    '경상북도': 14,
    '경상남도': 15,
    '제주특별자치도': 16
}

# %% [markdown]
# #### 방법1, 2 둘 중 하나 또는 그 외 본인만의 방법으로 작성하시면 됩니다 :)

# %%
df = df_target.copy()

# %%
df = df.groupby('광역')['광역'].count()
df2 = pd.DataFrame(df)

# %%
df3 = df2.sort_index(key=lambda x: x.map(province_dict))
df3 = df3.rename(columns={'광역': '박물관미술관수'})

# %%
df_result = df3

# %%
check_04_01(df_result)
display(df_result)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 70 / 100
#          박물관미술관수
# 광역
# 서울특별시        198
# 부산광역시         48
# 대구광역시         23
# 인천광역시         42
# 광주광역시         49
# 대전광역시         23
# 울산광역시         11
# 세종특별자치시        8
# 경기도          219
# 강원도          133
# 충청북도          62
# 충청남도          76
# 전라북도          81
# 전라남도         107
# 경상북도          89
# 경상남도          97
# 제주특별자치도       95

# %% [markdown]
# ### 문제 4-2) 원하는 정보 얻기 02 (10점)
# - 3단계의 DataFrame(df_target)을 이용하여 아래의 조건에 맞는 정보를 구하세요.
# <br></br>
#     - 광역자치단체-기초자치단체(행정시)의 박물관/미술관의 총 수가 8개인 광역-기초자치단체(행정시)를 확인하고자 합니다.
# <br></br>
# <br></br>
#     - 조건1: df_target의 '광역'과 '기초' Column(열)에 있는 광역자치단체/기초자치단체(행정시) data를 이용하여 광역자치단체-기초자치단체(행정시)별 박물관/미술관의 총 수가 8개인 곳을 찾아주세요.
# <br></br>
#     - 조건2: 결과 DataFrame의 '광역' Column(열)에 광역자치단체를, '기초' Column(열)에 기초자치단체(행정시)를 입력해주세요.
# <br></br>
#     - 조건3: '광역' Column(열)은 4-1문제와 같이 광역자치단체의 우선순위에 따라 나열해주세요.
#         - 4-1의 province_dict 참고
# <br></br>
#     - 조건4: 같은 광역자치단체가 있다면, '기초' Column(열)의 data는 가나다 순의 역순으로 나열해주세요.
# <br></br>
#     - 조건5: 결과 DataFrame의 박물관/미술관의 총 수를 나타내는 Column(열)의 이름은 '박물관미술관수' 입니다.
# <br></br>
#         - 예시: 박물관미술관수가 9개인 광역-기초자치단체(행정시)
# <br></br>
#         <img src="images/05-4-2-001.png" style="margin:auto" width=200/>
# <br></br>
#     - 조건6: Index는 숫자(정수) 오름차순으로 설정해주세요.
# <br></br>
#     - 조건7: 'df_result' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_result)를 check_04_02 함수에 입력하여 채점하세요.

# %%
df4 = df_target.copy()

# %%
df4['기초'] = df4['기초'].fillna('세종')

# %%
df4['기초'].unique()
# Out:
# array(['광주시', '남양주시', '파주시', '포천시', '이천시', '용인시', '과천시', '여주시', '김포시',
#        '화성시', '고양시', '안산시', '부천시', '양평군', '양주시', '안성시', '시흥시', '의왕시',
#        '광명시', '수원시', '동구', '종로구', '순창군', '완주군', '전주시', '정선군', '울주군',
#        '용산구', '당진시', '오산시', '동두천시', '연천군', '성남시', '하남시', '안양시', None,
#        '구리시', '중구', '남구', '북구', '유성구', '대덕구', '서구', '광양시', '곡성군', '연수구',
#        '무주군', '미추홀구', '강화군', '남동구', '부평구', '달성군', '영월군', '수성구', '달서구',
#        '익산시', '정읍시', '고창군', '군산시', '남원시', '김제시', '임실군', '진안군', '홍성군',
#        '부여군', '공주시', '예산군', '태안군', '아산시', '금산군', '원주시', '서천군', '천안시',
#        '청양군', '음성군', '괴산군', '청주시', '충주시', '논산시', '보령시', '제천시', '증평군',
#        '진천군', '옥천군', '영동군', '단양군', '강릉시', '인제군', '춘천시', '보은군', '진도군',
#        '평창군', '횡성군', '고성군', '화천군', '삼척시', '양구군', '양양군', '태백시', '홍천군',
#        '속초시', '강진군', '제주시', '서귀포시', '통영시', '진주시', '양산시', '거제시', '밀양시',
#        '합천군', '사천시', '창원시', '김해시', '하동군', '창녕군', '함안군', '함양군', '산청군',
#        '의령군', '예천군', '안동시', '영천시', '문경시', '김천시', '포항시', '경주시', '칠곡군',
#        '봉화군', '군위군', '경산시', '거창군', '고령군', '울진군', '의성군', '영주시', '상주시',
#        '청도군', '청송군', '구미시', '무안군', '영양군', '나주시', '해남군', '장성군', '영암군',
#        '장흥군', '화순군', '담양군', '보성군', '순천시', '영광군', '구례군', '여수시', '목포시',
#        '완도군', '신안군', '함평군', '부안군', '고흥군', '동해시', '의정부시', '가평군', '강남구',
#        '송파구', '서초구', '성동구', '노원구', '관악구', '해운대구', '사하구', '금정구', '은평구',
#        '강서구', '성북구', '영등포구', '서대문구', '강동구', '계양구', '장수군', '서산시', '마포구',
#        '강북구', '광산구', '구로구', '광진구', '동대문구', '사상구', '영도구', '연제구', '도봉구',
#        '남해군', '동래구', '부산진구', '동작구', '기장군', '울릉군'], dtype=object)

# %%
# 조건1
df4 = df4.groupby(['광역', '기초'])['광역'].count()
df5 = pd.DataFrame(df4)

# %%
# 조건2
df5 = df5[df5['광역'] == 8].rename(columns={'광역': '박물관미술관수'})
df5
# Out:
#               박물관미술관수
# 광역      기초
# 경기도     성남시         8
#         화성시         8
# 부산광역시   해운대구        8
# 세종특별자치시 세종          8
# 인천광역시   미추홀구        8
# 전라남도    강진군         8
#         영암군         8
# 충청남도    예산군         8

# %%
# 정렬
df6 = df5.sort_index(level=1, ascending=False)
df6 = df6.sort_index(level='광역', key=lambda x: x.map(province_dict), sort_remaining=False)

# %%
df6
# Out:
#               박물관미술관수
# 광역      기초
# 부산광역시   해운대구        8
# 인천광역시   미추홀구        8
# 세종특별자치시 세종          8
# 경기도     화성시         8
#         성남시         8
# 충청남도    예산군         8
# 전라남도    영암군         8
#         강진군         8

# %%
df6 = df6.reset_index()

# %%
df6
# Out:
#         광역    기초  박물관미술관수
# 0    부산광역시  해운대구        8
# 1    인천광역시  미추홀구        8
# 2  세종특별자치시    세종        8
# 3      경기도   화성시        8
# 4      경기도   성남시        8
# 5     충청남도   예산군        8
# 6     전라남도   영암군        8
# 7     전라남도   강진군        8

# %%
for idx, row in df6.iterrows():
    if row['광역'] == '세종특별자치시':
        df6.at[idx, '기초'] = None

# %%
df_result = df6

# %%
# 4-2

check_04_02(df_result)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 80 / 100

# %%
df_result.head(2)
# Out:
#       광역    기초  박물관미술관수
# 0  부산광역시  해운대구        8
# 1  인천광역시  미추홀구        8

# %% [markdown]
# ### 문제 4-3) 원하는 정보 얻기 03 (10점)
# - 3단계의 DataFrame(df_target)을 이용하여 아래의 조건에 맞는 정보를 구하세요.
# <br></br>
#     - 광역자치단체-박물관미술관구분(사립, 국립, 공립, 대학)의 평균 관람료 차이를 알아보고자 합니다.
# <br></br>
# <br></br>
#     - 조건1: df_target의 '광역'과 '박물관미술관구분' Column(열)에 있는 광역자치단체/박물관미술관구분 data를 이용하여 광역자치단체-박물관미술관구분별 평균 어른관람료-평균 어린이관람료 간 차이가 가장 크고 작은 곳을 찾아주세요.
#         - 단, 어른관람료 또는 어린이관람료가 둘 중 하나라도 0원(무료)인 박물관/미술관의 경우 평균 계산에서 제외해주세요.
# <br></br>
#     - 조건3: 결과 DataFrame의 '광역' Index에 광역자치단체를, '박물관미술관구분' Index에 박물관미술관구분를 입력해주세요.
# <br></br>
#     - 조건4: '광역' Index은 4-1문제와 같이 광역자치단체의 우선순위에 따라 나열해주세요.
#         - 4-1의 province_dict 참고
# <br></br>
#     - 조건5: 결과 DataFrame의 '어른관람료' Column(열)은 광역자치단체-박물관미술관구분별 평균 어른 관람료를, '어린이관람료' Column(열)은 광역자치단체-박물관미술관구분별 평균 어린이 관람료를,  '관람료차이' Column(열)은 광역자치단체-박물관미술관구분별 평균 어른 관람료 - 평균 어린이 관람료(차액)을 입력해주세요.
#         - 어른/어린이 관람료 및 관람료차이는 평균값에서 소숫점 첫째 자리에서 반올림한 정수 값을 입력해주세요.
#             - 예시: 2978.5원 -> 2980.0원(소숫점 첫째 자리에서 반올림) -> 2980원(정수 값)
# <br></br>
#         - 예시: 청소년관람료-어린이관람료 차이가 가장 크고 작은 광역자치단체-박물관미술관구분
# <br></br>
#         <img src="images/05-4-3-001.png" style="margin:auto" width=400/>
# <br></br>
#     - 조건6: 'df_result' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_result)를 check_04_03 함수에 입력하여 채점하세요.

# %%
df8 = df_target.copy()

# %%
# 조건 1
filter_adult = df8[df8['어른관람료'] != 0]
filter_child = df8[df8['어린이관람료'] != 0]

# %%
adult = filter_adult.groupby(['광역', '박물관미술관구분'])['어른관람료'].mean()
child = filter_child.groupby(['광역', '박물관미술관구분'])['어린이관람료'].mean()
df9 = pd.DataFrame(adult)
df10 = pd.DataFrame(child)

# %%
df11 = pd.concat([df9, df10], axis=1)

# %%
df11['관람료차이'] = df11['어른관람료'] - df11['어린이관람료']

# %%
df11.head(2)
# Out:
#                     어른관람료       어린이관람료        관람료차이
# 광역  박물관미술관구분
# 강원도 공립        2692.307692  1692.000000  1000.307692
#     사립        8725.000000  5488.095238  3236.904762

# %%
max = df11[df11['관람료차이'] == df11['관람료차이'].max()]
min = df11[df11['관람료차이'] == df11['관람료차이'].min()]
max,min
# Out:
# (               어른관람료       어린이관람료        관람료차이
#  광역  박물관미술관구분
#  강원도 사립        8725.0  5488.095238  3236.904762,
#                     어른관람료  어린이관람료  관람료차이
#  광역      박물관미술관구분
#  세종특별자치시 사립        2500.0  3000.0 -500.0)

# %%
df12 = pd.concat([max, min], axis=0)

# %%
df12 = df12.sort_index(level='광역', key=lambda x: x.map(province_dict))

# %%
df12 = df12.round(-1).astype(int)
df12
# Out:
#                   어른관람료  어린이관람료  관람료차이
# 광역      박물관미술관구분
# 세종특별자치시 사립         2500    3000   -500
# 강원도     사립         8720    5490   3240

# %%
df_result = df12

# %%
# 4-3
import numpy as np

check_04_03(df_result)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 90 / 100

# %%
df_result.head(2)
# Out:
#                   어른관람료  어린이관람료  관람료차이
# 광역      박물관미술관구분
# 세종특별자치시 사립         2500    3000   -500
# 제주특별자치도 사립        10670    7710   2960

# %% [markdown]
# ### 문제 4-4) 원하는 정보 얻기 04 (10점)
# - 3단계의 DataFrame(df_target)을 이용하여 아래의 조건에 맞는 정보를 구하세요.
# <br></br>
#     - 가족(어른2, 청소년1, 어린이1)이 공휴일에 제주특별자치도 제주시에 있는 미술관을 관람하려 합니다. 총 관람료가 2만원 이하, 공휴일 4시간 이상 관람 가능한 미술관 list를 보여주세요.
# <br></br>
# <br></br>
#     - 조건1: 가족(어른 2명, 청소년 1명, 어린이 1명)의 총 관람료가 2만원 이하여야 합니다.
# <br></br>
#     - 조건2: 제주특별자치도의 제주시에 있는 미술관을 가려고 합니다.
#         - 미술관: 이 Test에서는 df_target의 시설명 Column(열)에 있는 data 중 <'미술관' 또는 '갤러리' 또는 '아트'> 라는 글자들이 포함되어 있는 곳을 '미술관'이라고 정의합니다.
# <br></br>
#     - 조건3: 공휴일에 가고자 합니다. 공휴일에 4시간 이상 관람 가능한 미술관이어야 합니다.
# <br></br>
#     - 조건4: 미술관 List의 Frame은 df_target과 동일합니다.
# <br></br>
#         - 예시: 서울특별시 송파구에서 가족(어른2, 청소년1, 어린이1)이 총 관람료 2만원 이내로 공휴일에 4시간 이상 관람할 수 있는 박물관 List
# <br></br>
#         <img src="images/05-4-4-001.png" style="margin:auto" width=800/>
# <br></br>
#     - 조건5: 'df_result' 변수에 결과 DataFrame을 할당하세요.
# <br></br>
# <br></br>
# - 완료 후 결과 dataframe 변수(df_result)를 check_04_04 함수에 입력하여 채점하세요.

# %%
ad.at[1, '어른관람료']
# Out:
# 5000

# %%
ad = df_target.copy()

# %%
budget = 20000
# 조건 1
test = ad[ad['어른관람료'] * 2 + ad['청소년관람료'] + ad['어린이관람료'] <= budget]
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1216 entries, 0 to 2112
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시설명        1216 non-null   object
#  1   박물관미술관구분   1216 non-null   object
#  2   소재지도로명주소   1216 non-null   object
#  3   평일관람시작시각   1216 non-null   object
#  4   평일관람종료시각   1216 non-null   object
#  5   공휴일관람시작시각  1216 non-null   object
#  6   공휴일관람종료시각  1216 non-null   object
#  7   어른관람료      1216 non-null   int32
#  8   청소년관람료     1216 non-null   int32
#  9   어린이관람료     1216 non-null   int32
#  10  데이터기준일자    1216 non-null   object
#  11  평일관람가능시간   1216 non-null   float64
#  12  공휴일관람가능시간  1216 non-null   float64
#  13  광역         1216 non-null   object
#  14  기초         1208 non-null   object
#  15  상세         1216 non-null   object
# dtypes: float64(2), int32(3), object(11)
# memory usage: 147.2+ KB

# %%
# 조건 2 -1
test = test[test['기초'] == '제주시']
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 556 to 1743
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시설명        24 non-null     object
#  1   박물관미술관구분   24 non-null     object
#  2   소재지도로명주소   24 non-null     object
#  3   평일관람시작시각   24 non-null     object
#  4   평일관람종료시각   24 non-null     object
#  5   공휴일관람시작시각  24 non-null     object
#  6   공휴일관람종료시각  24 non-null     object
#  7   어른관람료      24 non-null     int32
#  8   청소년관람료     24 non-null     int32
#  9   어린이관람료     24 non-null     int32
#  10  데이터기준일자    24 non-null     object
#  11  평일관람가능시간   24 non-null     float64
#  12  공휴일관람가능시간  24 non-null     float64
#  13  광역         24 non-null     object
#  14  기초         24 non-null     object
#  15  상세         24 non-null     object
# dtypes: float64(2), int32(3), object(11)
# memory usage: 2.9+ KB

# %%
# 조건 2 - 2
test = test[test['시설명'].str.contains('미술관|갤러리|아트')]
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 1107 to 1240
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시설명        5 non-null      object
#  1   박물관미술관구분   5 non-null      object
#  2   소재지도로명주소   5 non-null      object
#  3   평일관람시작시각   5 non-null      object
#  4   평일관람종료시각   5 non-null      object
#  5   공휴일관람시작시각  5 non-null      object
#  6   공휴일관람종료시각  5 non-null      object
#  7   어른관람료      5 non-null      int32
#  8   청소년관람료     5 non-null      int32
#  9   어린이관람료     5 non-null      int32
#  10  데이터기준일자    5 non-null      object
#  11  평일관람가능시간   5 non-null      float64
#  12  공휴일관람가능시간  5 non-null      float64
#  13  광역         5 non-null      object
#  14  기초         5 non-null      object
#  15  상세         5 non-null      object
# dtypes: float64(2), int32(3), object(11)
# memory usage: 620.0+ bytes

# %%
test = test[test['공휴일관람가능시간'] >= 4] 
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 1107 to 1240
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시설명        5 non-null      object
#  1   박물관미술관구분   5 non-null      object
#  2   소재지도로명주소   5 non-null      object
#  3   평일관람시작시각   5 non-null      object
#  4   평일관람종료시각   5 non-null      object
#  5   공휴일관람시작시각  5 non-null      object
#  6   공휴일관람종료시각  5 non-null      object
#  7   어른관람료      5 non-null      int32
#  8   청소년관람료     5 non-null      int32
#  9   어린이관람료     5 non-null      int32
#  10  데이터기준일자    5 non-null      object
#  11  평일관람가능시간   5 non-null      float64
#  12  공휴일관람가능시간  5 non-null      float64
#  13  광역         5 non-null      object
#  14  기초         5 non-null      object
#  15  상세         5 non-null      object
# dtypes: float64(2), int32(3), object(11)
# memory usage: 620.0+ bytes

# %%
test.head()
# Out:
#              시설명 박물관미술관구분                       소재지도로명주소 평일관람시작시각 평일관람종료시각  \
# 1107    제주옹기숨미술관       사립    제주특별자치도 제주시 주르레길 55-19(해안동)    10:00    17:00
# 1185     제주도립미술관       공립  제주특별자치도 제주시 1100로 2894-78(연동)    09:00    18:00
# 1187     제주현대미술관       공립       제주특별자치도 제주시 한경면 저지14길 35    09:00    18:00
# 1192       성안미술관       사립      제주특별자치도 제주시 중앙로 470(아라일동)    10:00    18:00
# 1240  제주도립김창열미술관       공립      제주특별자치도 제주시 한림읍 용금로 883-5    09:00    18:00
#
#      공휴일관람시작시각 공휴일관람종료시각  어른관람료  청소년관람료  어린이관람료     데이터기준일자  평일관람가능시간  \
# 1107     10:00     17:00      0       0       0  2022-06-16       7.0
# 1185     09:00     18:00   2000    1000     500  2022-06-16       9.0
# 1187     09:00     18:00   2000    1000     500  2022-06-16       9.0
# 1192     10:00     18:00      0       0       0  2022-06-16       8.0
# 1240     09:00     18:00   2000    1000     500  2022-06-16       9.0
#
#       공휴일관람가능시간       광역   기초                 상세
# 1107        7.0  제주특별자치도  제주시    주르레길 55-19(해안동)
# 1185        9.0  제주특별자치도  제주시  1100로 2894-78(연동)
# 1187        9.0  제주특별자치도  제주시       한경면 저지14길 35
# 1192        8.0  제주특별자치도  제주시      중앙로 470(아라일동)
# 1240        9.0  제주특별자치도  제주시      한림읍 용금로 883-5

# %%
df_result = test

# %%
check_04_04(df_result)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 100 / 100

# %%
df_result.head(2)
# Out:
#              시설명 박물관미술관구분                       소재지도로명주소 평일관람시작시각 평일관람종료시각  \
# 1107  제주옹기 숨 미술관       사립    제주특별자치도 제주시 주르레길 55-19(해안동)    10:00    17:00
# 1185     제주도립미술관       공립  제주특별자치도 제주시 1100로 2894-78(연동)    09:00    18:00
#
#      공휴일관람시작시각 공휴일관람종료시각  어른관람료  청소년관람료  어린이관람료     데이터기준일자  평일관람가능시간  \
# 1107     10:00     17:00      0       0       0  2022-06-16       7.0
# 1185     09:00     18:00   2000    1000     500  2022-06-16       9.0
#
#       공휴일관람가능시간       광역   기초                 상세
# 1107        7.0  제주특별자치도  제주시    주르레길 55-19(해안동)
# 1185        9.0  제주특별자치도  제주시  1100로 2894-78(연동)

# %% [markdown]
# ***
#
# ### 🎊 문제가 끝났습니다. 제출양식과 일정에 맞춰 제출해주시기를 바랍니다!
#
# ### 제출양식
# - 이 파일은 EDA TEST 5회차 노트북입니다. 따라서 제출시 파일명은 아래와 같습니다.
# - [DS]edalvtest_05_yourname.ipynb
#
# ***

# %% [markdown]
# # 문의사항 및 의견이 있는 경우 작성해주세요.

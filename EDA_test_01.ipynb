# %% [markdown]
# <div align="center">
#     <img src="images/zb-logo.png" alt="제로베이스" width="100%">
#     <br>
#     <a href="https://zerobaseschool.notion.site/DS-EDA-Lv-Test-b7d5e895c7cd4dda813c8fe2f2c23f79"><img src="images/openinnotion_logo.png" alt="EDA Lv Test Doc" width="12%"></a>
#
# 이 Jupyter Notebook 파일은 <a href="https://zero-base.co.kr/category_data_camp/school_DS">제로베이스</a>에서 제공하는 **EDA Level Test** 문제입니다.<br>
# 지금까지 공부하신 내용으로 데이터 분석에 대해 좀 더 연습할 수 있는 시간이 되셨으면 좋겠습니다.🙂<br>
# **EDA Level Test**에 대한 안내 사항은 상단 **Open in ZeroBase Notion** 로고를 클릭하여 확인해주세요!<br>
# 반드시 시작 전에 내용을 숙지해주시기를 바랍니다!<br>
# </div>
#
# ***

# %% [markdown]
# <h1 style="background-color:#9F81F7;color:#D8D8D8;font-weight:bold;display:inline-block;padding: 5px">EDA Level Test 01 ⭐️</h1>
#
# | Week | Data Analysis | Difficulty | This Notebook |
# |------|---------------|------------|-------|
# | 1    | 서울시 인구 데이터 | ⭐️ |👈|
# | 2    | 화장품 성분 데이터 | ⭐️⭐️⭐️ ||
# | 3    | 올림픽 데이터 | ⭐️⭐️ ||
# | 4    | 국가별 인터넷 사용률 데이터 |⭐️⭐️ ||
# | 5    | 전국 박물관/미술관 정보 표준 데이터 | ⭐️⭐️⭐️ ||
# | 6    | 서울시 흡연율 통계 데이터 | ⭐️⭐️ ||
# | 7    | 웹크롤링 | ⭐️ ||
# | 8    | 서울시 지하철 호선별 역별 유/무임 승하차 인원 정보 데이터 | ⭐️⭐️ ||
# | 9    | 서울시 교통사고 현황 (사고유형별) 통계 데이터 | ⭐️⭐️ ||
# | 10   | 서울시 교통사고 현황 (사고유형별) 통계 + 서울시 차량통행속도 (구별/월별) 통계 + 서울시 인구밀도 (구별) 통계 | ⭐️⭐️⭐️ ||

# %% [markdown]
# ## 문제 소개 및 데이터 준비 단계
#
# <div style="border: 1px solid black; padding: 10px;">
#
# ### 문제 소개
# - 총 3단계 데이터 분석 상황 제시 (총 100점)
#     - 1단계 DataFrame 불러오기 & 전처리 (30점)
#     - 2단계 원하는 정보 얻기 (30점)
#     - 3단계 시각화 (40점)
#     - 시각화 단계는 채점 코드가 없습니다. 요구 조건에 맞는 그래프를 작성해주신 후 제출해주세요!
#
# ### Data 원본 출처
# - Source: [서울시 열린데이터](https://data.seoul.go.kr/dataList/419/S/2/datasetView.do)
# - Data Download: [PinkWink Blog](https://pinkwink.kr/attachment/cfile1.uf@99740C3A5ECB0EA52889B3.txt)
#
# ### 참고사항
# * 데이터는 탭으로 구분하여 TXT 파일 형식으로 제공
# * 외국인 세대수 제외
# * 65세이상 고령자 수: 외국인 포함
#
# </div>

# %% [markdown]
# ## 문제 시작! 🏃🏻

# %% [markdown]
# ### 1단계: DataFrame 불러오기 & 전처리
# ***

# %% [markdown]
# ### **문제 1-1)** 0, 1, 2번 index의 row를 제거하고 index를 초기화 하세요(기존 index는 삭제(drop)하세요).    (10점)
#
# - 예시: 0,1,2번 index 제거
# <br></br>
#     <img src="images/01-1-1-001.png" style="margin:auto" width=130/>
#     <img src="images/01-1-1-002.png" style="margin:auto" width=180 height=180/>
#
# - 예시: index 초기화
# <br></br>
#     <img src="images/01-1-1-002.png" style="margin:auto" width=150/>
#     <img src="images/01-1-1-003.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_01 함수에 입력하여 채점하세요.

# %% [markdown]
# <h4 style="background-color:#9F81F7;color:#FBEFF2;font-weight:bold;display:inline-block;padding: 5px">채점 방법</h4>
#
# <div style="border: 1px solid black; padding: 10px;">
#
# 1. grading 모듈 불러오기
# ```python
#     from grading import *
# ```
# 2. 채점 코드 통과
# - 각 문제마다 번호에 맞는 채점 코드를 통과시켜주세요
#     - check_01_01(df), check_01_02(df) ...
# 3. 채점 코드까지 통과시킨 후, 제출!
#
# 사용 예시
# ```python
# check_01_01(df)
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 10 / 100
# ```
# </div>

# %%
 from grading import *

# %%
import pandas as pd
import numpy as np

# %%
data = {'A':[0,1,2,3,4],
'B':[6,7,8,9,10]}
df = pd.DataFrame(data)
df
# Out:
#    A   B
# 0  0   6
# 1  1   7
# 2  2   8
# 3  3   9
# 4  4  10

# %%
df = df.drop([0,1,2])
df
# Out:
#    A   B
# 3  3   9
# 4  4  10

# %%
df.index = [0,1]
df
# Out:
#    A   B
# 0  3   9
# 1  4  10

# %%
df = pd.read_csv('datas/report.txt', sep = "\t", engine='python', encoding = 'utf-8')
df.head()
# Out:
#          기간  자치구         세대          인구       인구.1       인구.2       인구.3  \
# 0        기간  자치구         세대          합계         합계         합계        한국인
# 1        기간  자치구         세대           계         남자         여자          계
# 2  2020.1/4   합계  4,354,006  10,013,781  4,874,995  5,138,786  9,733,655
# 3  2020.1/4  종로구     74,151     161,984     78,271     83,713    151,217
# 4  2020.1/4   중구     63,045     136,469     66,769     69,700    126,175
#
#         인구.4       인구.5     인구.6     인구.7     인구.8  세대당인구   65세이상고령자
# 0        한국인        한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 1         남자         여자        계       남자       여자  세대당인구   65세이상고령자
# 2  4,742,217  4,991,438  280,126  132,778  147,348   2.24  1,518,239
# 3     73,704     77,513   10,767    4,567    6,200   2.04     28,073
# 4     61,839     64,336   10,294    4,930    5,364      2     23,794

# %%
df = pd.read_csv('datas/report.txt', sep = "\t", engine='python', encoding = 'utf-8', header=2, thousands=',')
df.head()
# Out:
#          기간  자치구       세대         계       남자       여자      계.1     남자.1  \
# 0  2020.1/4   합계  4354006  10013781  4874995  5138786  9733655  4742217
# 1  2020.1/4  종로구    74151    161984    78271    83713   151217    73704
# 2  2020.1/4   중구    63045    136469    66769    69700   126175    61839
# 3  2020.1/4  용산구   110895    246165   119961   126204   229579   110667
# 4  2020.1/4  성동구   135643    307193   149891   157302   299042   146300
#
#       여자.1     계.2    남자.2    여자.2  세대당인구  65세이상고령자
# 0  4991438  280126  132778  147348   2.24   1518239
# 1    77513   10767    4567    6200   2.04     28073
# 2    64336   10294    4930    5364   2.00     23794
# 3   118912   16586    9294    7292   2.07     39439
# 4   152742    8151    3591    4560   2.20     44728

# %%
df = df.drop([0], axis=0)

# %%
df = df.reset_index(drop=True)

# %%
check_01_01(df)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %% [markdown]
# ### **문제 1-2)** 현재의 컬럼명(current_columns)을 아래 new_columns와 같이 변경하세요.      (10점)
#
# - current_columns = ['기간', '자치구', '세대', '인구', '인구.1', '인구.2', '인구.3', '인구.4', '인구.5', '인구.6', '인구.7', '인구.8', '세대당인구', '65세이상고령자']
# <br></br>
# - new_columns = ['기간', '자치구', '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '세대당인구', '65세이상고령자']
# <br></br>
# - 예시
# <br></br>
#     <img src="./images/01-1-2-001.png" style="margin:auto" width=150/>
#     <img src="./images/01-1-2-002.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_02 함수에 입력하여 채점하세요.

# %%
df1 = pd.read_csv('datas/report.txt', sep = "\t", engine='python', encoding = 'utf-8', header=2, thousands=',')
df1.head(10)
# Out:
#          기간   자치구       세대         계       남자       여자      계.1     남자.1  \
# 0  2020.1/4    합계  4354006  10013781  4874995  5138786  9733655  4742217
# 1  2020.1/4   종로구    74151    161984    78271    83713   151217    73704
# 2  2020.1/4    중구    63045    136469    66769    69700   126175    61839
# 3  2020.1/4   용산구   110895    246165   119961   126204   229579   110667
# 4  2020.1/4   성동구   135643    307193   149891   157302   299042   146300
# 5  2020.1/4   광진구   165287    365990   176226   189764   350417   169568
# 6  2020.1/4  동대문구   165279    362793   178202   184591   346156   171896
# 7  2020.1/4   중랑구   182220    400678   198122   202556   395619   196076
# 8  2020.1/4   성북구   193801    454532   218561   235971   442494   213926
# 9  2020.1/4   강북구   144805    316750   154141   162609   312985   152747
#
#       여자.1     계.2    남자.2    여자.2  세대당인구  65세이상고령자
# 0  4991438  280126  132778  147348   2.24   1518239
# 1    77513   10767    4567    6200   2.04     28073
# 2    64336   10294    4930    5364   2.00     23794
# 3   118912   16586    9294    7292   2.07     39439
# 4   152742    8151    3591    4560   2.20     44728
# 5   180849   15573    6658    8915   2.12     48989
# 6   174260   16637    6306   10331   2.09     60367
# 7   199543    5059    2046    3013   2.17     66764
# 8   228568   12038    4635    7403   2.28     72172
# 9   160238    3765    1394    2371   2.16     61660

# %%
df1.columns =  ['기간', '자치구', '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '세대당인구', '65세이상고령자']
df1.drop([0], axis=0, inplace=True)
df1.head()
# Out:
#          기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 1  2020.1/4  종로구   74151  161984   78271   83713  151217   73704   77513
# 2  2020.1/4   중구   63045  136469   66769   69700  126175   61839   64336
# 3  2020.1/4  용산구  110895  246165  119961  126204  229579  110667  118912
# 4  2020.1/4  성동구  135643  307193  149891  157302  299042  146300  152742
# 5  2020.1/4  광진구  165287  365990  176226  189764  350417  169568  180849
#
#    등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자
# 1    10767      4567      6200   2.04     28073
# 2    10294      4930      5364   2.00     23794
# 3    16586      9294      7292   2.07     39439
# 4     8151      3591      4560   2.20     44728
# 5    15573      6658      8915   2.12     48989

# %%
# 1-2
check_01_02(df1)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %% [markdown]
# ### **문제 1-3)** 천단위 구분자 " , "를 제거하고, data의 type을 int 또는 float으로 변경하세요.   (10점)
# - 기간, 자치구: 변경 없음
# <br></br>
# - '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '65세이상고령자': 천단위 구분자 "," 제거 및 int로 타입 변경
# <br></br>
#     - 예시
# <br></br>
#     <img src="./images/01-1-3-001.png" style="margin:auto" width=150/>
#     <img src="./images/01-1-3-002.png" style="margin:auto" width=150/>
# <br></br>
# - '세대당인구': float으로 타입 변경
# <br></br>
#     - 예시
# <br></br>
#     <img src="./images/01-1-3-003.png" style="margin:auto" width=150/>
#     <img src="./images/01-1-3-004.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_03 함수에 입력하여 채점하세요.

# %%
df2 = df1.copy() 
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   기간        25 non-null     object
#  1   자치구       25 non-null     object
#  2   세대        25 non-null     int64
#  3   합계        25 non-null     int64
#  4   남자        25 non-null     int64
#  5   여자        25 non-null     int64
#  6   한국인 계     25 non-null     int64
#  7   한국인 남자    25 non-null     int64
#  8   한국인 여자    25 non-null     int64
#  9   등록외국인 계   25 non-null     int64
#  10  등록외국인 남자  25 non-null     int64
#  11  등록외국인 여자  25 non-null     int64
#  12  세대당인구     25 non-null     float64
#  13  65세이상고령자  25 non-null     int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 2.9+ KB

# %%
# 1-3

check_01_03(df2)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %% [markdown]
# ## 2단계: 원하는 정보 얻기

# %% [markdown]
# ### *Pandas DataFrame의 기능을 이용하여 아래 문제의 답을 구하세요.*
# ***
# #### 서울시는 아래와 같이 5개의 권역으로 구분됩니다.
# ![서울시 권역생활권](https://www.seoulsolution.kr/sites/default/files/images/%EC%B2%B4%EA%B3%846.jpg)
# - ref: [서울시-도시계획체계](https://www.seoulsolution.kr/ko/content/서울시-도시계획체계)
#
# - 도심권: ['종로구', '중구', '용산구']
# - 동북권: ['성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구']
# - 서북권: ['은평구', '서대문구', '마포구']
# - 서남권: ['양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구']
# - 동남권: ['서초구', '강남구', '송파구', '강동구']
# ***

# %%
region_dict = {'도심권': ['종로구', '중구', '용산구'],
               '동북권': ['성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구'],
               '서북권': ['은평구', '서대문구', '마포구'],
               '서남권': ['양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구'],
               '동남권': ['서초구', '강남구', '송파구', '강동구']
               }

# %% [markdown]
# ### **문제 2-1)** 1단계에서 구한 DataFrame에 '권역' column을 추가하여 해당 구에 맞는 권역을 입력하세요.    (5점)
#
# - 예시
# <br></br>
#     <img src="./images/01-2-1-001.png" style="margin:auto" width=150/>
#     <img src="./images/01-2-1-002.png" style="margin:auto" width=200/>
#
# - 완료 후 결과 dataframe 변수를 check_02_01 함수에 입력하여 채점하세요.

# %%
col1 = []
col2 = []
for key, value in region_dict.items():
    for i in value: 
        col1.append(key)
        col2.append(i)

col1[:5], col2[:5]
# Out:
# (['도심권', '도심권', '도심권', '동북권', '동북권'], ['종로구', '중구', '용산구', '성동구', '광진구'])

# %%
df3 = pd.DataFrame(data= {'자치구' : col2, '권역': col1})
df3.head()
# Out:
#    자치구   권역
# 0  종로구  도심권
# 1   중구  도심권
# 2  용산구  도심권
# 3  성동구  동북권
# 4  광진구  동북권

# %%
# 2-1

check_02_01(df3)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %% [markdown]
# ### **문제 2-2)** 2-1에서 만든 DataFrame을 이용하여 Pandas의 pivot_table 메소드를 활용하여 각 권역별 아래 값의 합을 구하고, '합계'를 기준으로 내림차순 정렬하세요.      (5점)
#
# - 구할 값: ['합계', '세대', '여자', '한국인 계', '등록외국인 계', '65세이상고령자']
#
# - 참고: [Pivot Table](https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html)
# <br></br>
#     - 예시
# <br></br>
#     <img src="./images/01-2-2-001.png" style="margin:auto" width=150/>
#     <img src="./images/01-2-2-002.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_02 함수에 입력하여 채점하세요.

# %%
df4 =  pd.merge(df2, df3, on='자치구')
# df4.info()
df4.head()
# Out:
#          기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0  2020.1/4  종로구   74151  161984   78271   83713  151217   73704   77513
# 1  2020.1/4   중구   63045  136469   66769   69700  126175   61839   64336
# 2  2020.1/4  용산구  110895  246165  119961  126204  229579  110667  118912
# 3  2020.1/4  성동구  135643  307193  149891  157302  299042  146300  152742
# 4  2020.1/4  광진구  165287  365990  176226  189764  350417  169568  180849
#
#    등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역
# 0    10767      4567      6200   2.04     28073  도심권
# 1    10294      4930      5364   2.00     23794  도심권
# 2    16586      9294      7292   2.07     39439  도심권
# 3     8151      3591      4560   2.20     44728  동북권
# 4    15573      6658      8915   2.12     48989  동북권

# %%
df_pivot = pd.pivot_table(df4, values =['합계', '세대', '여자', '한국인 계', '등록외국인 계', '65세이상고령자'] ,index=['권역'], aggfunc=np.sum)
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계
# 권역
# 도심권     91306    37647   248091   279617   506971   544618
# 동남권    286874    20511   876524  1097300  2102113  2122624
# 동북권    497385    67938  1342778  1580313  3008988  3076926
# 서남권    454108   124791  1360162  1554745  2950352  3075143
# 서북권    188566    29239   526451   626811  1165231  1194470

# %%
df_pivot.sort_values(by='합계', ascending=False, inplace=True)

# %% [markdown]
# >>> table = pd.pivot_table(df, values='D', index=['A', 'B'],
# ...                        columns=['C'], aggfunc=np.sum)
# >>> table
# C        large  small
# A   B
# bar one    4.0    5.0
#     two    7.0    6.0
# foo one    4.0    1.0
#     two    NaN    6.0

# %% [markdown]
# >>> df
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
# 2-2

check_02_02(df_pivot)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계
# 권역
# 동북권    497385    67938  1342778  1580313  3008988  3076926
# 서남권    454108   124791  1360162  1554745  2950352  3075143
# 동남권    286874    20511   876524  1097300  2102113  2122624
# 서북권    188566    29239   526451   626811  1165231  1194470
# 도심권     91306    37647   248091   279617   506971   544618

# %% [markdown]
# ### **문제 2-3)** 2-2에서 만든 Pivot Table을 이용하여 각 권역별 ['고령자비율', '외국인비율', '여성비율', '세대당인구'] 컬럼을 만들어 아래와 같이 값을 입력하고 '외국인비율'을 기준으로 오름차순 정렬하세요.  (5점)
#
# - 고령자비율: 65세이상고령자 / 합계 * 100
#
# - 외국인비율: 등록외국인 계 / 합계 * 100
#
# - 여성비율: 여자 / 합계 * 100
#
# - 세대당인구: (합계 - 등록외국인 계) / 세대
# <br></br>
# - 예시: B/C 비율 및  B 기준 오름차순 정렬
# <br></br>
#     <img src="./images/01-2-2-002.png" style="margin:auto" width=150/>
#     <img src="./images/01-2-3-001.png" style="margin:auto" width=230/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_03 함수에 입력하여 채점하세요.

# %%
df_pivot['고령자비율'] = df_pivot['65세이상고령자'] /df_pivot['합계'] * 100
df_pivot['외국인비율'] = df_pivot['등록외국인 계'] /df_pivot['합계'] * 100
df_pivot['여성비율'] = df_pivot['여자'] /df_pivot['합계'] * 100
df_pivot['세대당인구'] = (df_pivot['합계'] - df_pivot['등록외국인 계']) / df_pivot['세대']
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동북권  2.207983  51.360124  2.240868
# 서남권  4.058055  50.558462  2.169118
# 동남권  0.966304  51.695449  2.398238
# 서북권  2.447864  52.476077  2.213370
# 도심권  6.912552  51.341858  2.043488

# %%
df_pivot.sort_values(by='외국인비율', ascending=True, inplace=True)
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동남권  0.966304  51.695449  2.398238
# 동북권  2.207983  51.360124  2.240868
# 서북권  2.447864  52.476077  2.213370
# 서남권  4.058055  50.558462  2.169118
# 도심권  6.912552  51.341858  2.043488

# %%
# 2-3

check_02_03(df_pivot)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동남권  0.966304  51.695449  2.398238
# 동북권  2.207983  51.360124  2.240868
# 서북권  2.447864  52.476077  2.213370
# 서남권  4.058055  50.558462  2.169118
# 도심권  6.912552  51.341858  2.043488

# %% [markdown]
# ### **문제 2-4)** 2-1에서 만든 DataFrame을 이용하여 각 구별 ['고령자비율', '외국인비율', '여성비율'] 컬럼을 만들어 아래와 같이 값을 입력하고 '세대당인구'을 기준으로 내림차순 정렬하세요.  (5점)
# - 고령자비율: 65세이상고령자 / 합계 * 100
# - 외국인비율: 등록외국인 계 / 합계 * 100
# - 여성비율: 여자 / 합계 * 100
# - 완료 후 결과 dataframe 변수를 check_02_04 함수에 입력하여 채점하세요.

# %%
df4.head(2)
# Out:
#          기간  자치구     세대      합계     남자     여자   한국인 계  한국인 남자  한국인 여자  \
# 0  2020.1/4  종로구  74151  161984  78271  83713  151217   73704   77513
# 1  2020.1/4   중구  63045  136469  66769  69700  126175   61839   64336
#
#    등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역
# 0    10767      4567      6200   2.04     28073  도심권
# 1    10294      4930      5364   2.00     23794  도심권

# %%
df4['고령자비율'] = df4['65세이상고령자'] / df4['합계'] * 100 
df4['외국인비율'] = df4['등록외국인 계'] / df4['합계'] * 100 
df4['여성비율'] = df4['여자'] / df4['합계'] * 100 
df4.tail(2)
# Out:
#           기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 23  2020.1/4  송파구  279301  680883  329058  351825  674095  325859  348236
# 24  2020.1/4  강동구  190019  457042  225226  231816  452646  223189  229457
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 23     6788      3199      3589   2.41     89539  동남권  13.150424  0.996941
# 24     4396      2037      2359   2.38     66401  동남권  14.528424  0.961837
#
#          여성비율
# 23  51.671873
# 24  50.720940

# %%
df4.sort_values(by='세대당인구', ascending=False, inplace=True)
df4.head(2)
# Out:
#           기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 14  2020.1/4  양천구  177436  460532  226109  234423  456339  224241  232098
# 21  2020.1/4  서초구  173580  434801  207877  226924  430568  205787  224781
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 14     4193      1868      2325   2.57     62761  서남권  13.627935  0.910469
# 21     4233      2090      2143   2.48     58332  동남권  13.415793  0.973549
#
#          여성비율
# 14  50.902652
# 21  52.190312

# %%
# 2-4

check_02_04(df4)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %% [markdown]
# ### **문제 2-5)** 2-3에서 만든 DataFrame을 이용하여 ['고령자비율', '외국인비율', '여성비율', '세대당인구']간의 피어슨 상관계수 행렬(Correlation matrix)를 구하세요. (10점)
#
# - 참고
#     - 상관계수(correlation coefficient): 두 변수가 함께 변하는 정도를 -1 ~ +1 범위의 수로 나타낸 것
#
#     - 피어슨 상관계수: 칼 피어슨(Karl Pearson)이 개발한 상관계수로, 일반적으로 상관계수라고 하면 피어슨 상관계수를 말함
#         - Standard Correlation Coefficient
#         - r(상관계수) = X와 Y가 함께 변하는 정도 / X와 Y가 각각 변하는 정도
# <br></br>
#     - 상관계수 행렬(Correlation Matrix): 변수간 상관계수를 보여주는 행렬
# <br></br>
#         - 예시: dog와 cat간의 상관계수 행렬
# <br></br>
#         <img src='./images/01-2-5-001.png' width=150>
#         <img src='./images/01-2-5-002.png' width=350>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_05 함수에 입력하여 채점하세요.

# %%
pivot_corr = df_pivot[['고령자비율', '외국인비율', '여성비율', '세대당인구']]

# %%
pivot_corr = pivot_corr.corr()

# %%
# 2-5

check_02_05(pivot_corr)
pivot_corr
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 60 / 60
#           고령자비율     외국인비율      여성비율     세대당인구
# 고령자비율  1.000000  0.655428  0.079476 -0.809536
# 외국인비율  0.655428  1.000000 -0.380941 -0.943776
# 여성비율   0.079476 -0.380941  1.000000  0.283602
# 세대당인구 -0.809536 -0.943776  0.283602  1.000000

# %% [markdown]
# ## 3단계: 시각화

# %% [markdown]
# ### *Pandas DataFrame의 Plot기능, Matplotlib.pyplot, Seaborn 등 시각화 Library를 이용하여 문제에서 제시하는 조건에 맞게 시각화하세요.*
# ***

# %%
# 한글 설정
import seaborn as sns
import platform
import matplotlib.pyplot as plt

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
# get_ipython().run_line_magic('matplotlib', 'inline')

# %% [markdown]
# ### **문제 3-1)** 자치구별 고령자비율을 내림차순에 따라 barh 그래프로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./images/01-3-1-001.png" style="margin:auto" width=400/>

# %%
df4.head()
# Out:
#           기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 14  2020.1/4  양천구  177436  460532  226109  234423  456339  224241  232098
# 21  2020.1/4  서초구  173580  434801  207877  226924  430568  205787  224781
# 10  2020.1/4  노원구  217148  535495  258696  276799  531037  256726  274311
# 23  2020.1/4  송파구  279301  680883  329058  351825  674095  325859  348236
# 9   2020.1/4  도봉구  138595  333495  162774  170721  331238  161879  169359
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 14     4193      1868      2325   2.57     62761  서남권  13.627935  0.910469
# 21     4233      2090      2143   2.48     58332  동남권  13.415793  0.973549
# 10     4458      1970      2488   2.45     82682  동북권  15.440294  0.832501
# 23     6788      3199      3589   2.41     89539  동남권  13.150424  0.996941
# 9      2257       895      1362   2.39     60023  동북권  17.998171  0.676772
#
#          여성비율
# 14  50.902652
# 21  52.190312
# 10  51.690305
# 23  51.671873
# 9   51.191472

# %%
df5 = df4.set_index('자치구')

# %%
df5.head()
# Out:
#            기간      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 자치구
# 양천구  2020.1/4  177436  460532  226109  234423  456339  224241  232098
# 서초구  2020.1/4  173580  434801  207877  226924  430568  205787  224781
# 노원구  2020.1/4  217148  535495  258696  276799  531037  256726  274311
# 송파구  2020.1/4  279301  680883  329058  351825  674095  325859  348236
# 도봉구  2020.1/4  138595  333495  162774  170721  331238  161879  169359
#
#      등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 자치구
# 양천구     4193      1868      2325   2.57     62761  서남권  13.627935  0.910469
# 서초구     4233      2090      2143   2.48     58332  동남권  13.415793  0.973549
# 노원구     4458      1970      2488   2.45     82682  동북권  15.440294  0.832501
# 송파구     6788      3199      3589   2.41     89539  동남권  13.150424  0.996941
# 도봉구     2257       895      1362   2.39     60023  동북권  17.998171  0.676772
#
#           여성비율
# 자치구
# 양천구  50.902652
# 서초구  52.190312
# 노원구  51.690305
# 송파구  51.671873
# 도봉구  51.191472

# %%
df5.sort_values(by='고령자비율', ascending=True, inplace=True)

# %%
df5['고령자비율'].plot(kind='barh',figsize=(10,10));

# %% [markdown]
# ### **문제 3-2)** 권역별 등록외국인 계를 PIE chart로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./images/01-3-2-001.png" style="margin:auto" width=400/>

# %%
df_pivot.head()
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동남권  0.966304  51.695449  2.398238
# 동북권  2.207983  51.360124  2.240868
# 서북권  2.447864  52.476077  2.213370
# 서남권  4.058055  50.558462  2.169118
# 도심권  6.912552  51.341858  2.043488

# %%
# 3-2: Pie
plt.figure(figsize=(8,6))
plt.title('권역별 외국인 비율')
plt.pie(df_pivot['등록외국인 계'], labels=df_pivot.index)
plt.show()

# %% [markdown]
# ### **문제 3-3)** 권역별 외국인비율을 Box plot으로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./images/01-3-3-001.png" style="margin:auto" width=400/>

# %%
# boxplot
plt.figure(figsize=(8,6))
plt.title('권역별 외국인 비율')
sns.boxplot(x='권역', y='외국인비율', data=df4)
plt.show()

# %% [markdown]
# ### **문제 3-4)** 자치구별 외국인비율-세대당인구를 Scatter plot에 나타내고, 상관관계에 따른 Regression Line을 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./images/01-3-4-001.png" style="margin:auto" width=400/>

# %%
sns.set_style('darkgrid')
sns.lmplot(x='세대당인구', y='외국인비율', data=df4, height=7);
plt.show()
# Out:
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 50808 (\N{HANGUL SYLLABLE OE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50808 (\N{HANGUL SYLLABLE OE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\HoJin\anaconda3\envs\ds_study\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ***
#
# ### 🎊 문제가 끝났습니다. 제출양식과 일정에 맞춰 제출해주시기를 바랍니다!
#
# ### 제출양식
# - 이 파일은 EDA TEST 1회차 노트북입니다. 따라서 제출시 파일명은 아래와 같습니다.
# - [DS]edalvtest_01_yourname.ipynb
#
# ***

# %% [markdown]
# # 문의사항 및 의견이 있는 경우 작성해주세요.

# %% [markdown]
# - 1번문제에 대한 설명이 조금 불친절 한거 같습니다. grab 파일을 열어보고나서 문제를 이해 하였습니다.
# - 3-4번 문제에서 한글이 깨지는 이유도 모르겠습니다. 다른 부분에서는 한글이 깨지지않는데 lmplot에서만 한글이 깨지는 오류가 생기네요
